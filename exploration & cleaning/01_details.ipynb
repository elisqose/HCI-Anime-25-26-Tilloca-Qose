# %% [markdown]
# # 01 – Details
#
# Esplorazione e data cleaning del dataset `details.csv`.
#
# **Colonne:**
# | Colonna | Descrizione |
# |---|---|
# | `mal_id` | ID univoco dell'anime su MyAnimeList |
# | `title` | Titolo dell'anime |
# | `title_japanese` | Titolo in giapponese |
# | `url` | URL della pagina MAL dell'anime |
# | `image_url` | URL dell'immagine di copertina |
# | `type` | Tipo (TV, Movie, etc) |
# | `status` | Stato di trasmissione |
# | `score` | Punteggio medio |
# | `scored_by` | Numero di utenti che hanno votato |
# | `start_date` | Data di inizio trasmissione |
# | `end_date` | Data di fine trasmissione |
# | `synopsis` | Sinossi testuale |
# | `rank` | Classifica globale |
# | `popularity` | Popolarità |
# | `members` | Numero di utenti che hanno l'anime nella loro lista |
# | `favorites` | Numero di utenti che hanno messo l'anime tra i preferiti |
# | `genres` | Lista di generi |
# | `studios` | Lista di studi di produzione |
# | `themes` | Lista di temi narrativi |
# | `demographics` | Lista di target demografici |
# | `source` | Materiale di origine (Manga, Novel, Original, etc) |
# | `rating` | Classificazione per età |
# | `episodes` | Numero di episodi |
# | `season` | Stagione di uscita |
# | `year` | Anno di uscita |
# | `producers` | Lista di produttori |
# | `explicit_genres` | Lista di generi espliciti |
# | `licensors` | Lista di licenziatari |
# | `streaming` | Lista di piattaforme di streaming |

# %% [markdown]
# ## 1. Import e caricamento dati
# Importiamo le librerie necessarie e carichiamo il file csv. Facciamo una esplorazione generica per capire la struttura e le caratteristiche del dataset.

# %%
import pandas as pd
import numpy as np
from dataset_analyzer import analyze

df_details = pd.read_csv('../datasets/details.csv')
print(f'Shape: {df_details.shape}')
print()
df_details.info()
df_details.head()
# Out:
# Shape: (28955, 29)
#
# <class 'pandas.DataFrame'>
# RangeIndex: 28955 entries, 0 to 28954
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mal_id           28955 non-null  int64
#  1   title            28955 non-null  str
#  2   title_japanese   28836 non-null  str
#  3   url              28955 non-null  str
#  4   image_url        28955 non-null  str
#  5   type             28888 non-null  str
#  6   status           28955 non-null  str
#  7   score            18882 non-null  float64
#  8   scored_by        18882 non-null  float64
#  9   start_date       28104 non-null  str
#  10  end_date         11267 non-null  str
#  11  synopsis         23828 non-null  str
#  12  rank             21997 non-null  float64
#  13  popularity       28955 non-null  int64
#  14  members          28955 non-null  int64
#  15  favorites        28955 non-null  int64
#  16  genres           28955 non-null  str
#  17  studios          28955 non-null  str
#  18  themes           28955 non-null  str
#  19  demographics     28955 non-null  str
#  20  source           28955 non-null  str
#  21  rating           28355 non-null  str
#  22  episodes         28275 non-null  float64
#  23  season           6266 non-null   str
#  24  year             6266 non-null   float64
#  25  producers        28955 non-null  str
#  26  explicit_genres  28955 non-null  str
#  27  licensors        28955 non-null  str
#  28  streaming        28955 non-null  str
# dtypes: float64(5), int64(4), str(20)
# memory usage: 6.4 MB
#    mal_id                             title        title_japanese  \
# 0   59356                          -Socket-              -socket-
# 1   56036                            ......                ......
# 2    2928              .hack//G.U. Returner  .HACK//G.U. RETURNER
# 3    3269               .hack//G.U. Trilogy   .hack//G.U. Trilogy
# 4    4469  .hack//G.U. Trilogy: Parody Mode   .hack//G.U. Trilogy
#
#                                                  url  \
# 0       https://myanimelist.net/anime/59356/-Socket-
# 1              https://myanimelist.net/anime/56036/-
# 2  https://myanimelist.net/anime/2928/hack__GU_Re...
# 3  https://myanimelist.net/anime/3269/hack__GU_Tr...
# 4  https://myanimelist.net/anime/4469/hack__GU_Tr...
#
#                                            image_url     type  \
# 0  https://cdn.myanimelist.net/images/anime/1043/...    Movie
# 1  https://cdn.myanimelist.net/images/anime/1057/...    Music
# 2  https://cdn.myanimelist.net/images/anime/1798/...      OVA
# 3  https://cdn.myanimelist.net/images/anime/1566/...    Movie
# 4  https://cdn.myanimelist.net/images/anime/10/86...  Special
#
#             status  score  scored_by                 start_date  ...  \
# 0  Finished Airing    NaN        NaN  2010-01-01T00:00:00+00:00  ...
# 1  Finished Airing   6.53      503.0  2023-06-11T00:00:00+00:00  ...
# 2  Finished Airing   6.65     9745.0  2007-01-18T00:00:00+00:00  ...
# 3  Finished Airing   7.06    15373.0  2007-12-22T00:00:00+00:00  ...
# 4  Finished Airing   6.35     4317.0  2008-03-25T00:00:00+00:00  ...
#
#   demographics    source                     rating  episodes  season  year  \
# 0           []  Original               G - All Ages       1.0     NaN   NaN
# 1           []  Original  PG-13 - Teens 13 or older       1.0     NaN   NaN
# 2           []      Game  PG-13 - Teens 13 or older       1.0     NaN   NaN
# 3           []      Game  PG-13 - Teens 13 or older       1.0     NaN   NaN
# 4           []      Game  PG-13 - Teens 13 or older       1.0     NaN   NaN
#
#                             producers explicit_genres  \
# 0         ['Nagoya Zokei University']              []
# 1                                  []              []
# 2  ['Bandai Visual', 'CyberConnect2']              []
# 3                   ['Bandai Visual']              []
# 4                   ['Bandai Visual']              []
#
#                                 licensors streaming
# 0                                      []        []
# 1                                      []        []
# 2                                      []        []
# 3  ['Funimation', 'Bandai Entertainment']        []
# 4                                      []        []
#
# [5 rows x 29 columns]

# %% [markdown]
# Il dataset contiene **28.955 righe** e **29 colonne**. Alcune colonne presentano valori nulli. Alcuni dtype richiedono conversione: le date sono in formato stringa, e alcune colonne intere (`scored_by`, `rank`, `episodes`, `year`) sono memorizzate come `float64`. Quiesti veranno analizzati e gestiti singolarmente nella sezione 2.

# %% [markdown]
# ## 1.1 Rimozione duplicati esatti
#
# Prima dell'analisi per colonna, rimuoviamo le righe con valori identici in **tutte** le colonne, mantenendo solo la prima occorrenza.

# %%
n_originale = len(df_details)

mask_dup = df_details.duplicated(keep=False)
n_righe_coinvolte = mask_dup.sum()
n_gruppi = df_details[mask_dup].duplicated(keep='first').sum()
n_tenute = n_righe_coinvolte - n_gruppi

print(f'Righe totali coinvolte in duplicazioni : {n_righe_coinvolte:,}')
print(f'  → prime occorrenze mantenute         : {n_tenute:,}')
print(f'  → occorrenze extra rimosse           : {n_gruppi:,}')
print()

df_details.drop_duplicates(keep='first', inplace=True)
print(f'Righe prima della rimozione : {n_originale:,}')
print(f'Righe dopo la rimozione     : {len(df_details):,}')
# Out:
# Righe totali coinvolte in duplicazioni : 0
#   → prime occorrenze mantenute         : 0
#   → occorrenze extra rimosse           : 0
#
# Righe prima della rimozione : 28,955
# Righe dopo la rimozione     : 28,955

# %% [markdown]
# ## 2. Analisi colonna per colonna

# %% [markdown]
# ### 2.1 `mal_id`
#
# È la **chiave primaria** del dataset. Deve essere intera, non nulla e univoca. Utilizziamo `analyze` per verificare queste proprietà.

# %%
analyze(df_details['mal_id'])
# Out:
#   Nome serie                     mal_id
#   dtype                          int64
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           NUMERICO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,955  (100.00%)
#   Null / NaN                     0  (0.00%)
#   Zeri                           0  (0.00%)
#   Positivi                       28,955   (100.00%)
#   Negativi                       0   (0.00%)
#   Valori unici                   28,955  (100.00%)
#
# Statistiche descrittive
# ────────────────────────────────────────────────────────────────────────────────
#
#   Min                            1
#   Max                            62,590
#   Range                          62,589
#   Media                          33,977.52
#   Mediana                        37,969.00
#   Moda/e                         1, 5, 6
#   Dev. standard                  19,616.86
#   Varianza                       384,821,140
#   Errore std (SEM)               115.2836
#   IQR  (Q3 − Q1)                 34,980.50
#   Q1  (25° pct)                  15,454.00
#   Q3  (75° pct)                  50,434.50
#   P5  ( 5° pct)                  1,591.70
#   P95 (95° pct)                  60,286.20
#   Coefficiente di variazione     57.73%
#
# Analisi outlier
# ────────────────────────────────────────────────────────────────────────────────
#
#   Soglia bassa  (Q1 − 1.5×IQR)   -37,016.75
#   Soglia alta   (Q3 + 1.5×IQR)   102,905.25
#   Outlier rilevati               0  (0.00%)
#
# Distribuzione
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   1 – 3,130                           2,830     9.8%
#   3,130 – 6,259                       1,681     5.8%
#   6,259 – 9,389                       1,217     4.2%
#   9,389 – 12,518                      1,019     3.5%
#   12,518 – 15,648                       519     1.8%
#   15,648 – 18,777                       662     2.3%
#   18,777 – 21,907                       587     2.0%
#   21,907 – 25,036                       704     2.4%
#   25,036 – 28,166                       466     1.6%
#   28,166 – 31,295                     1,150     4.0%
#   31,295 – 34,424                     1,494     5.2%
#   34,424 – 37,554                     1,898     6.6%
#   37,554 – 40,683                     1,907     6.6%
#   40,683 – 43,813                     1,496     5.2%
#   43,813 – 46,942                     2,135     7.4%
#   46,942 – 50,072                     1,756     6.1%
#   50,072 – 53,201                     1,639     5.7%
#   53,201 – 56,331                     1,876     6.5%
#   56,331 – 59,460                     1,974     6.8%
#   59,460 – 62,590                     1,945     6.7%
#
# Valori estremi
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più grandi:
#     #1   62,590
#     #2   62,589
#     #3   62,584
#     #4   62,582
#     #5   62,580
#     #6   62,572
#     #7   62,568
#     #8   62,567
#     #9   62,566
#     #10  62,564
#
#   I 10 più piccoli:
#     #1   1
#     #2   5
#     #3   6
#     #4   7
#     #5   8
#     #6   15
#     #7   16
#     #8   17
#     #9   18
#     #10  19
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#                 Valore    Conteggio        %
#   ────────────────────   ──────────   ──────
#                 59,356            1     0.0%
#                 56,036            1     0.0%
#                  2,928            1     0.0%
#                  3,269            1     0.0%
#                  4,469            1     0.0%
#                    454            1     0.0%
#                  1,143            1     0.0%
#                    299            1     0.0%
#                  9,332            1     0.0%
#                 10,390            1     0.0%
#
#   I 10 meno frequenti:
#                 Valore    Conteggio        %
#   ────────────────────   ──────────   ──────
#                 56,606            1     0.0%
#                 34,895            1     0.0%
#                 36,305            1     0.0%
#                 31,245            1     0.0%
#                 59,421            1     0.0%
#                 58,303            1     0.0%
#                 52,512            1     0.0%
#                 45,069            1     0.0%
#                 45,187            1     0.0%
#                 46,436            1     0.0%

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 28.955 record hanno un ID univoco.
# - **Nessun duplicato**: ogni riga corrisponde a un anime distinto.
# - **Dtype corretto**: `int64`, nessuna conversione necessaria.
#
# **Nessuna pulizia necessaria.**

# %% [markdown]
# ### 2.2 `title`
#
# Colonna testuale con il titolo dell'anime. Verifichiamo la presenza di valori nulli e duplicati.

# %%
df_details['title'] = df_details['title'].str.strip()
analyze(df_details['title'])
# Out:
#   Nome serie                     title
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,955  (100.00%)
#   Null / NaN                     0  (0.00%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   28,953  (99.99%)
#   Valori duplicati               2  (0.01%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  1  caratteri
#   Lunghezza max                  186  caratteri
#   Lunghezza media                24.70  caratteri
#   Lunghezza mediana              21.0000  caratteri
#   Dev. standard lunghezza        15.07
#   IQR lunghezza                  18.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ───────────────────────────────────────────────────
#    #1         186   Shinjiteita Nakama-tachi ni Dungeon Okuchi de Koro…
#    #2         141   99-kai Danzai sareta Loop Reijou desu ga Konse wa …
#    #3         140   Shoukan Showcase: Isekai Teni shita Saki de Fennec…
#    #4         132   Mukuwarenakatta Murabito A, Kizoku ni Hirowarete D…
#    #5         130   Kanchigai no Atelier Meister: Eiyuu Party no Moto …
#    #6         130   NEET Kunoichi to Nazeka Dousei Hajimemashita: Naze…
#    #7         126   Watashi no Naka no Gensou-teki Sekaikan Oyobi Sono…
#    #8         124   Kochira Katsushikaku Kameari Kouenmae Hashutsujo: …
#    #9         120   Kochira Katsushikaku Kameari Kouenmae Hashutsujo: …
#   #10         120   Tsuujou Kougeki ga Zentai Kougeki de Ni-kai Kougek…
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────
#    #1           1   2
#    #2           1   9
#    #3           1   ◯
#    #4           1   F
#    #5           1   K
#    #6           1   M
#    #7           1   Q
#    #8           1   R
#    #9           1   T
#   #10           1   X
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   1 – 10                              3,742    12.9%
#   10 – 19                             9,458    32.7%
#   19 – 28                             6,669    23.0%
#   28 – 38                             4,282    14.8%
#   38 – 47                             2,418     8.4%
#   47 – 56                             1,192     4.1%
#   56 – 65                               639     2.2%
#   65 – 75                               269     0.9%
#   75 – 84                               154     0.5%
#   84 – 93                                61     0.2%
#   93 – 102                               30     0.1%
#   102 – 112                              23     0.1%
#   112 – 121                              10     0.0%
#   121 – 130                               4     0.0%
#   130 – 139                               1     0.0%
#   139 – 149                               2     0.0%
#   149 – 158                               0     0.0%
#   158 – 167                               0     0.0%
#   167 – 176                               0     0.0%
#   176 – 186                               1     0.0%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore                                     Conteggio      %
#   ────────────────────────────────────────   ─────────   ────
#   Moonlight                                          2   0.0%
#   Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian           2   0.0%
#   -Socket-                                           1   0.0%
#   ......                                             1   0.0%
#   .hack//G.U. Returner                               1   0.0%
#   .hack//G.U. Trilogy                                1   0.0%
#   .hack//G.U. Trilogy: Parody Mode                   1   0.0%
#   .hack//Gift                                        1   0.0%
#   .hack//Intermezzo                                  1   0.0%
#   .hack//Liminality                                  1   0.0%
#
#   I 10 meno frequenti (più rari):
#   Valore                                                Conteggio      %
#   ───────────────────────────────────────────────────   ─────────   ────
#   Zutto Tomodachi                                               1   0.0%
#   Zutto Suki Datta                                              1   0.0%
#   Zutto Mae kara Suki deshita. Kokuhaku Jikkou Iinka…           1   0.0%
#   Zutto Mae kara Suki deshita. Kokuhaku Jikkou Iinka…           1   0.0%
#   Zutaboro Reijou wa Ane no Moto Konyakusha ni Dekia…           1   0.0%
#   Zurukute Sugoi                                                1   0.0%
#   Zurui Maboroshi                                               1   0.0%
#   Zuqiu Wangzhe                                                 1   0.0%
#   Zuqiu Jianghu                                                 1   0.0%
#   Zuoyou Nao Zhili Kaifa                                        1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 3,715  (12.8%)
#   Contiene maiuscole             28,915  (99.9%)
#   Contiene minuscole             28,861  (99.7%)
#   Contiene spazi                 26,023  (89.9%)
#   Contiene caratteri speciali    12,572  (43.4%)
#   Contiene URL                   1  (0.0%)
#   Contiene @                     53  (0.2%)
#   Solo numerico                  14
#   Solo alfabetico                2,302
#   Solo alfanumerico              2,332
#
# Analisi parole / token
# ────────────────────────────────────────────────────────────────────────────────
#
#   Parole medie per valore        4.08
#   Max parole                     30
#   Min parole                     1
#
#   Le 10 parole più comuni:
#   Parola                  Conteggio
#   ────────────────────   ──────────
#   no                          6,572
#   to                          1,207
#   Season                      1,051
#   ni                            817
#   wa                            777
#   -                             727
#   The                           713
#   Movie                         641
#   wo                            567
#   Xiao                          558

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 28.955 record hanno un titolo.
# - **Quasi univoco**: 28.953 valori distinti su 28.955. Ci solo 2 titoli duplicati che verifichiamo successivamente.
# - **Lunghezze variabili**: da 1 carattere a 186 caratteri. Stiampiamo i 10 più lunghi e 10 più corti e facciamo delle verifiche per approfondire.
# - **14 titoli solo numerici**: Indaghiamo in seguito.
# - **1 titolo contiene un URL**: Ingaghiamo in seguito.
# - **43.4% contiene caratteri speciali**: normale, i titoli includono punteggiatura, simboli e trattini.

# %%
# Titoli duplicati
dup_mask = df_details.duplicated(subset=['title'], keep=False)
print(f'Titoli duplicati (righe coinvolte): {dup_mask.sum()}')
print()
print(df_details[dup_mask][['mal_id', 'title', 'type', 'status', 'year']].to_string(index=False))

# Titoli solo numerici
print()
print('─' * 60)
num_mask = df_details['title'].str.fullmatch(r'\d+')
print(f'Titoli solo numerici: {num_mask.sum()}')
print()
print(df_details[num_mask][['mal_id', 'title', 'type', 'year']].to_string(index=False))

# Titolo che contiene un URL
print()
print('─' * 60)
url_mask = df_details['title'].str.contains(r'https?://', regex=True, na=False)
print(f'Titoli con URL: {url_mask.sum()}')
print()
print(df_details[url_mask][['mal_id', 'title', 'type', 'year']].to_string(index=False))

# Lunghezze estreme
print()
print('─' * 60)
lunghezze = df_details['title'].str.len()
top10_lunghi = df_details.loc[lunghezze.nlargest(10).index][['mal_id', 'title', 'type', 'year']]
top10_corti  = df_details.loc[lunghezze.nsmallest(10).index][['mal_id', 'title', 'type', 'year']]
print('10 titoli più lunghi:')
print(top10_lunghi.to_string(index=False))
print()
print('10 titoli più corti:')
print(top10_corti.to_string(index=False))

# Titoli con caratteri speciali
print()
print('─' * 60)
spec_mask = df_details['title'].str.contains(r'[^a-zA-Z0-9\s]', regex=True, na=False)
print(f'Titoli con caratteri speciali: {spec_mask.sum()}')
print()
print('Primi 10:')
print(df_details[spec_mask][['mal_id', 'title', 'type', 'year']].head(10).to_string(index=False))
# Out:
# Titoli duplicati (righe coinvolte): 4
#
#  mal_id                                    title  type          status  year
#   59994                                Moonlight Music Finished Airing   NaN
#   60524                                Moonlight Music Finished Airing   NaN
#   53367 Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian   ONA Finished Airing   NaN
#   55740 Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian   ONA Finished Airing   NaN
#
# ────────────────────────────────────────────────────────────
# Titoli solo numerici: 14
#
#  mal_id  title  type   year
#   29978    001   ONA    NaN
#   60145   1135 Music    NaN
#   37065    123 Music    NaN
#   55204   1985 Music    NaN
#   30234   1989 Music    NaN
#   38756      2 Music    NaN
#   54066   2005 Music    NaN
#   32813   2010 Music    NaN
#   53789     32 Music    NaN
#   53771   3341 Music    NaN
#   60486    520 Movie    NaN
#   13971 663114 Movie    NaN
#   41457     86    TV 2021.0
#   36089      9 Music    NaN
#
# ────────────────────────────────────────────────────────────
# Titoli con URL: 1
#
#  mal_id                                                                     title  type  year
#    8357 Himitsukessha Taka no Tsume The Movie 3: http://takanotsume.jp wa Eien ni Movie   NaN
#
# ────────────────────────────────────────────────────────────
# 10 titoli più lunghi:
#  mal_id                                                                                                                                                                                      title    type   year
#   60303 Shinjiteita Nakama-tachi ni Dungeon Okuchi de Korosarekaketa ga Gift "Mugen Gacha" de Level 9999 no Nakama-tachi wo Te ni Irete Moto Party Member to Sekai ni Fukushuu & "Zamaa!" Shimasu!      TV 2025.0
#   62002                                              99-kai Danzai sareta Loop Reijou desu ga Konse wa "Chouzetsu Aisare Mode" desu tte!? Shin no Chikara ni Mezamete Hajimaru 100-kaime no Jinsei     NaN    NaN
#   61127                                               Shoukan Showcase: Isekai Teni shita Saki de Fennec ga Akuma no Shouchou!? Bouken kara Tsuihou sareta node, Uta to Dance de Sekai wo Kaemasu!   Music    NaN
#   57005                                                       Mukuwarenakatta Murabito A, Kizoku ni Hirowarete Dekiai sareru Ue ni, Jitsu wa Motteita Densetsu-kyuu no Kami Skill mo Kakusei shita      TV    NaN
#   60140                                                         Kanchigai no Atelier Meister: Eiyuu Party no Moto Zatsuyougakari ga, Jitsu wa Sentou Igai ga SSS Rank Datta to Iu Yoku Aru Hanashi      TV 2025.0
#   61271                                                         NEET Kunoichi to Nazeka Dousei Hajimemashita: Nazeka Beach de Dogimagi Shimashita/Nazeka Moto Koutou Youma to Nakayoku Narimashita     ONA    NaN
#   36596                                                             Watashi no Naka no Gensou-teki Sekaikan Oyobi Sono Kengen wo Souki Saseta Aru Genjitsu de no Dekigoto ni Kansuru Ichi Kousatsu   Music    NaN
#   33879                                                               Kochira Katsushikaku Kameari Kouenmae Hashutsujo: Seton Tankentai! Sumidagawa no Chikai - Omoide no Shiroi Kujira wo Sagase! Special    NaN
#   33876                                                                   Kochira Katsushikaku Kameari Kouenmae Hashutsujo: Ryou-san to Chuuken Lucky Monogatari - Kameari Dai Houimou wo Kawase!! Special    NaN
#   40102                                                                   Tsuujou Kougeki ga Zentai Kougeki de Ni-kai Kougeki no Okaasan wa Suki desu ka? Namiuchigiwa no Okaasan wa Suki desu ka?     OVA    NaN
#
# 10 titoli più corti:
#  mal_id title  type   year
#   38756     2 Music    NaN
#   36089     9 Music    NaN
#   31687     ◯   ONA    NaN
#    6055     F    TV 1988.0
#   14467     K    TV 2012.0
#   50238     M Music    NaN
#   51608     Q Music    NaN
#   60502     R   ONA    NaN
#   52546     T   OVA    NaN
#     156     X    TV 2001.0
#
# ────────────────────────────────────────────────────────────
# Titoli con caratteri speciali: 12572
#
# Primi 10:
#  mal_id                                                 title    type  year
#   59356                                              -Socket-   Movie   NaN
#   56036                                                ......   Music   NaN
#    2928                                  .hack//G.U. Returner     OVA   NaN
#    3269                                   .hack//G.U. Trilogy   Movie   NaN
#    4469                      .hack//G.U. Trilogy: Parody Mode Special   NaN
#     454                                           .hack//Gift     OVA   NaN
#    1143                                     .hack//Intermezzo Special   NaN
#     299                                     .hack//Liminality     OVA   NaN
#    9332                                        .hack//Quantum     OVA   NaN
#   10390 .hack//Quantum: Sore ike! Bokura no Chimuchimu-chan!! Special   NaN

# %% [markdown]
# **Risultati dell'indagine:**
#
# - **Titoli duplicati (2 coppie, 4 righe):** `Moonlight` e `Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian` compaiono ciascuno due volte, ma con `mal_id` distinti. Sono anime separati su MAL che condividono il titolo. **Nessuna rimozione necessaria.**
#
# - **Titoli solo numerici (14 righe):** tutti legittimi. La maggior parte sono video musicali (`Music`) o cortometraggi in cui titoli brevi o numerici sono comuni. **Nessuna azione necessaria.**
#
# - **Titolo contenente un URL (1 riga):** `Himitsukessha Taka no Tsume The Movie 3: http://takanotsume.jp wa Eien ni` (`mal_id` 8357). L'URL è parte integrante del titolo ufficiale del film, caratteristica della serie *Taka no Tsume* nota per titoli volutamente assurdi. **Nessuna azione necessaria.**
#
# - **Lunghezze estreme:** i titoli molto corti (1–2 caratteri) sono anime reali con titoli brevi; i titoli molto lunghi (fino a 186 caratteri) sono tipici degli produzioni moderni. Nessun valore anomalo.
#
# - 43.4% dei titoli contiene caratteri speciali (12.572): percentuale alta ma attesa. Dai primi 10 stampati si nota che si tratta di punteggiatura e simboli che fanno   parte naturale titoli anime.
#
# **Conclusione:** la colonna `title` non richiede alcuna pulizia. Tutti i casi apparentemente anomali sono valori legittimi.

# %% [markdown]
# ### 2.3 `title_japanese`
#
# Colonna testuale con il titolo in giapponese. I null sono ammessi: anime di produzione non giapponese o senza titolo kanji registrato su MAL non avranno questo campo.

# %%
df_details['title_japanese'] = df_details['title_japanese'].str.strip()
analyze(df_details['title_japanese'])
# Out:
#   Nome serie                     title_japanese
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,836  (99.59%)
#   Null / NaN                     119  (0.41%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   27,772  (95.91%)
#   Valori duplicati               1,064  (3.67%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  1  caratteri
#   Lunghezza max                  85  caratteri
#   Lunghezza media                12.24  caratteri
#   Lunghezza mediana              10.0000  caratteri
#   Dev. standard lunghezza        8.69
#   IQR lunghezza                  10.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ─────────────────────────────────────────────────────────────────────────────────────────────────
#    #1          85   ラブライブ School idol project！μ's→NEXT LoveLive！2014～E…
#    #2          79   信じていた仲間達にダンジョン奥地で殺されかけたがギフト『無限ガチャ』でレベル9999の仲間達を手に入…
#    #3          78   SUPA DUPA FLY feat. 湘南乃風, MOOMIN, KENTY GROSS, BES…
#    #4          74   DANCE EVOLUTION DANCE MASTERS SILENT HILL ROBBIE !…
#    #5          74   Vivy -Fluorite Eye's Song- 特別総集編「-To make everyone…
#    #6          73   ユーリ!!! on ICE Yuri Plisetsky GPF in Barcelona EX "…
#    #7          69   Candy boy -Nonchalant talk of the certain twin sis…
#    #8          69   ラブライブ School idol project！μ's→NEXT LoveLive！2014～E…
#    #9          67   バンドリ！ ガールズバンドパーティ！ 5th Anniversary Animation -CiRC…
#   #10          66   Inter College Animation Festival (2004) (インターカレッジ・…
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────
#    #1           1   2
#    #2           1   9
#    #3           1   愛
#    #4           1   愛
#    #5           1   証
#    #6           1   足
#    #7           1   ◯
#    #8           1   缠
#    #9           1   창
#   #10           1   笛
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   1 – 5                               5,933    20.6%
#   5 – 9                               8,363    29.0%
#   9 – 13                              5,417    18.8%
#   13 – 17                             3,023    10.5%
#   17 – 22                             2,182     7.6%
#   22 – 26                             1,684     5.8%
#   26 – 30                               925     3.2%
#   30 – 34                               536     1.9%
#   34 – 38                               307     1.1%
#   38 – 43                               201     0.7%
#   43 – 47                               132     0.5%
#   47 – 51                                54     0.2%
#   51 – 55                                31     0.1%
#   55 – 59                                23     0.1%
#   59 – 64                                11     0.0%
#   64 – 68                                 6     0.0%
#   68 – 72                                 2     0.0%
#   72 – 76                                 3     0.0%
#   76 – 80                                 2     0.0%
#   80 – 85                                 1     0.0%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore                   Conteggio      %
#   ──────────────────────   ─────────   ────
#   おしりたんてい                   9   0.0%
#   僕のヒーローアカデミア           7   0.0%
#   ゲゲゲの鬼太郎                   5   0.0%
#   ゴールデンカムイ                 5   0.0%
#   ああっ女神さまっ                 4   0.0%
#   아기공룡 둘리                    4   0.0%
#   ぼのぼの                         4   0.0%
#   文豪ストレイドッグス             4   0.0%
#   キャットマン                     4   0.0%
#   地獄先生ぬ～べ～                 4   0.0%
#
#   I 10 meno frequenti (più rari):
#   Valore                                                             Conteggio      %
#   ────────────────────────────────────────────────────────────────   ─────────   ────
#   ずっと友達                                                                 1   0.0%
#   ずっと好きだった                                                           1   0.0%
#   ずっと前から好きでした。～告白実行委員会～ 「金曜日のおはよう」…           1   0.0%
#   ずっと前から好きでした。～告白実行委員会～                                 1   0.0%
#   ずたぼろ令嬢は姉の元婚約者に溺愛される                                     1   0.0%
#   ズルくてすごい                                                             1   0.0%
#   ズルい幻                                                                   1   0.0%
#   足球王者                                                                   1   0.0%
#   足球江湖                                                                   1   0.0%
#   左右脑智力开发                                                             1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 2,618  (9.1%)
#   Contiene maiuscole             6,097  (21.1%)
#   Contiene minuscole             3,300  (11.4%)
#   Contiene spazi                 10,741  (37.2%)
#   Contiene caratteri speciali    27,304  (94.7%)
#   Contiene URL                   0  (0.0%)
#   Contiene @                     10  (0.0%)
#   Solo numerico                  9
#   Solo alfabetico                598
#   Solo alfanumerico              621
#
# Analisi parole / token
# ────────────────────────────────────────────────────────────────────────────────
#
#   Parole medie per valore        1.65
#   Max parole                     14
#   Min parole                     1
#
#   Le 10 parole più comuni:
#   Parola                  Conteggio
#   ────────────────────   ──────────
#   THE                           418
#   ANIMATION                     237
#   劇場版                           231
#   The                           186
#   第二季                           160
#   of                            140
#   the                           136
#   2                             131
#   映画                            120
#   -                              92

# %% [markdown]
# **Osservazioni:**
# - **119 valori nulli** (~0.4%): strutturali, anime di produzione non giapponese o senza titolo kanji registrato su MAL.
# - Facciamo un controllo sui titoli duplicati, con lunghezze estreme, contenenti `@` e solo numerici.

# %%
cols = ['mal_id', 'title', 'title_japanese', 'type', 'year']

# Duplicati
dup_mask_tj = df_details['title_japanese'].duplicated(keep=False) & df_details['title_japanese'].notna()
print(f'Titoli giapponesi duplicati (righe coinvolte): {dup_mask_tj.sum()}')
print()
print('Primi 10:')
print(df_details[dup_mask_tj][cols].head(10).to_string(index=False))

# Lunghezze estreme
print()
print('─' * 60)
lunghezze_tj = df_details['title_japanese'].str.len()
print('10 titoli giapponesi più lunghi:')
print(df_details.loc[lunghezze_tj.nlargest(10).index, cols].to_string(index=False))
print()
print('10 titoli giapponesi più corti:')
print(df_details.loc[lunghezze_tj.nsmallest(10).index, cols].to_string(index=False))

# Titoli con @
print()
print('─' * 60)
at_mask_tj = df_details['title_japanese'].str.contains('@', regex=False, na=False)
print(f'Titoli giapponesi con @: {at_mask_tj.sum()}')
print()
print(df_details[at_mask_tj][cols].to_string(index=False))

# Solo numerici
print()
print('─' * 60)
num_mask_tj = df_details['title_japanese'].str.fullmatch(r'\d+', na=False)
print(f'Titoli giapponesi solo numerici: {num_mask_tj.sum()}')
print()
print(df_details[num_mask_tj][cols].to_string(index=False))
# Out:
# Titoli giapponesi duplicati (righe coinvolte): 2003
#
# Primi 10:
#  mal_id                                                 title      title_japanese       type   year
#    3269                                   .hack//G.U. Trilogy .hack//G.U. Trilogy      Movie    NaN
#    4469                      .hack//G.U. Trilogy: Parody Mode .hack//G.U. Trilogy    Special    NaN
#   41380            100-man no Inochi no Ue ni Ore wa Tatteiru    100万の命の上に俺は立っている         TV 2020.0
#   44881 100-man no Inochi no Ue ni Ore wa Tatteiru 2nd Season    100万の命の上に俺は立っている         TV 2021.0
#   48976      100-man no Inochi no Ue ni Ore wa Tatteiru Recap    100万の命の上に俺は立っている TV Special    NaN
#   32601                   12-sai.: Chicchana Mune no Tokimeki  12歳。～ちっちゃなムネのトキメキ～         TV 2016.0
#   33419        12-sai.: Chicchana Mune no Tokimeki 2nd Season  12歳。～ちっちゃなムネのトキメキ～         TV 2016.0
#    9624                                30-sai no Hoken Taiiku            30歳の保健体育         TV 2011.0
#   12131                       30-sai no Hoken Taiiku Specials            30歳の保健体育    Special    NaN
#   52162                                       5-Okunen Button              5億年ボタン         TV 2022.0
#
# ────────────────────────────────────────────────────────────
# 10 titoli giapponesi più lunghi:
#  mal_id                                                                                                                                                                                      title                                                                        title_japanese       type   year
#   30896                                                                                                 Love Live! School Idol Project: μ's →NEXT LoveLive! 2014 - Endless Parade Encore Animation ラブライブ School idol project！μ's→NEXT LoveLive！2014～ENDLESS PARADE～アンコールアニメーション 0209Ver.    Special    NaN
#   60303 Shinjiteita Nakama-tachi ni Dungeon Okuchi de Korosarekaketa ga Gift "Mugen Gacha" de Level 9999 no Nakama-tachi wo Te ni Irete Moto Party Member to Sekai ni Fukushuu & "Zamaa!" Shimasu!       信じていた仲間達にダンジョン奥地で殺されかけたがギフト『無限ガチャ』でレベル9999の仲間達を手に入れて元パーティーメンバーと世界に復讐＆『ざまぁ！』します!         TV 2025.0
#   38495                                                                                              Supa Dupa Fly feat. Shounan no Kaze, Moomin, Kenty Gross, Bes, Apollo, Natural Weapon, Doraku        SUPA DUPA FLY feat. 湘南乃風, MOOMIN, KENTY GROSS, BES, APOLLO, NATURAL WEAPON, 導楽      Music    NaN
#   53193                                                                                             Dance Dance Evolution Dance Masters Silent Hill Robbie!!!!!!!!!!! Kigurumi Usagi ga Odottemita            DANCE EVOLUTION DANCE MASTERS SILENT HILL ROBBIE !!!!!!!!!!! - 着ぐるみ兎が踊ってみた      Music    NaN
#   49241                                                                                                                         Vivy: Fluorite Eye's Song - To Make Everyone Happy With My Singing            Vivy -Fluorite Eye's Song- 特別総集編「-To make everyone happy with my singing-」 TV Special    NaN
#   35382                                                                                                                Yuri!!! on Ice: Yuri Plisetsky GPF in Barcelona EX - Welcome to The Madness             ユーリ!!! on ICE Yuri Plisetsky GPF in Barcelona EX "Welcome to The Madness"    Special    NaN
#    4535                                                                                                                       Candy Boy: Nonchalant Talk of the Certain Twin Sisters in Daily Life                 Candy boy -Nonchalant talk of the certain twin sisters in daily life-        ONA    NaN
#   25897                                                                                                     Love Live! School Idol Project: μ's →NEXT LoveLive! 2014 - Endless Parade Makuai Drama                 ラブライブ School idol project！μ's→NEXT LoveLive！2014～ENDLESS PARADE～幕間ドラマ    Special    NaN
#   51218                                                                                                                                BanG Dream! 5th Anniversary Animation: CiRCLE Thanks Party!                   バンドリ！ ガールズバンドパーティ！ 5th Anniversary Animation -CiRCLE THANKS PARTY！-        ONA    NaN
#    7459                                                                                                                                               The Collected Animations of ICAF (2001-2006)                    Inter College Animation Festival (2004) (インターカレッジ・アニメーション・フェスティバル)        OVA    NaN
#
# 10 titoli giapponesi più corti:
#  mal_id    title title_japanese  type  year
#   38756        2              2 Music   NaN
#   36089        9              9 Music   NaN
#    6535       Ai              愛 Movie   NaN
#   32294 Ai (ONA)              愛   ONA   NaN
#   51806   Akashi              証 Music   NaN
#   42865     Ashi              足 Music   NaN
#   31687        ◯              ◯   ONA   NaN
#   59024     Chan              缠 Movie   NaN
#   21025    Chang              창 Movie   NaN
#   29907      Fue              笛 Movie   NaN
#
# ────────────────────────────────────────────────────────────
# Titoli giapponesi con @: 10
#
#  mal_id                                             title                                   title_japanese       type   year
#   40589                      ColoColo Animal ABC@Kin Tele                                 コロコロアニマルABC@きんてれ         TV 2019.0
#   36743                Genki-kun no Christmas @ Tokyo-eki                                 原器くんのクリスマス @ 東京駅        ONA    NaN
#   36744               Genki-kun no Oshougatsu @ Tokyo-eki                                   原器くんのお正月 @ 東京駅        ONA    NaN
#   21635                                            GJ-bu@                                             GJ部@ TV Special    NaN
#   58598                          Guruguru@Mawaru@Mawaluna                                   ぐるぐる@まわる@まわルーナ      Music    NaN
#    2261                                       Malice@Doll                               Malice@doll マリスドール        OVA    NaN
#   39046                 Puchimas!: Petit iDOLM@STER (OVA)                         ぷちます! -PETIT IDOLM@STER-        OVA    NaN
#   14515                             Sasami-san@Ganbaranai                                     ささみさん@がんばらない         TV 2013.0
#   36186 The iDOLM@STER Prologue SideM: Episode of Jupiter THE IDOLM@STER Prologue SideM Episode of Jupiter    Special    NaN
#   49661                                           Voy@ger                                          VOY@GER        ONA    NaN
#
# ────────────────────────────────────────────────────────────
# Titoli giapponesi solo numerici: 9
#
#  mal_id  title title_japanese  type  year
#   29978    001            001   ONA   NaN
#   60145   1135           1135 Music   NaN
#   55204   1985           1985 Music   NaN
#   30234   1989           1989 Music   NaN
#   38756      2              2 Music   NaN
#   54066   2005           2005 Music   NaN
#   60486    520            520 Movie   NaN
#   13971 663114         663114 Movie   NaN
#   36089      9              9 Music   NaN

# %% [markdown]
# - I titoli giaponesi contenenti `@` corrispondono con titoli in inglese con `@` nella stessa posizione. Il carattere fa parte del titolo. Nessuna pulizia necessaria.
# - I titoli giaponesi solo numerici corrispondono a titoli in inglese anche loro solo numerici. Nessuna pulizia necessaria.
# - I titoli più corti come osservato dai primi 10 stampati mostrano una corrispondenza con i titoli in inglese e appartengono principalmente a brani musicali o film. Anche questo è atteso.
# - I titoli più lunghi seguono la stessa logica dei titoli più corti con l'eccezione di un titolo che è uguale a quello in inglese. Facciamo un controllo per vedere se è un caso isolato o se accade più volte.

# %%
# title == title_japanese
same_mask = df_details['title'] == df_details['title_japanese']
print(f'Titoli identici in title e title_japanese: {same_mask.sum()} ({same_mask.mean()*100:.1f}%)')
print()
print('Primi 10:')
print(df_details[same_mask][['mal_id', 'title', 'title_japanese', 'type', 'year']].head(10).to_string(index=False))
# Out:
# Titoli identici in title e title_japanese: 833 (2.9%)
#
# Primi 10:
#  mal_id                 title        title_japanese    type   year
#   56036                ......                ......   Music    NaN
#    3269   .hack//G.U. Trilogy   .hack//G.U. Trilogy   Movie    NaN
#    1143     .hack//Intermezzo     .hack//Intermezzo Special    NaN
#    9332        .hack//Quantum        .hack//Quantum     OVA    NaN
#     873          .hack//Roots          .hack//Roots      TV 2006.0
#    1487         .hack//Unison         .hack//Unison Special    NaN
#   29978                   001                   001     ONA    NaN
#   28761                 00:08                 00:08   Movie    NaN
#    7374                  100%                  100%     OVA    NaN
#   39208 100% Renewable Energy 100% Renewable Energy Special    NaN

# %% [markdown]
# Notiamo che ci sono 833 righe con nome in inglese uguale a quello in giaponese. Potrebbe trattarsi di opere senza nome giaponese. Abbiamo deciso di tenerlo invariato.
#
# **Nessuna pulizia necessaria**

# %% [markdown]
# ### 2.4 `url`
#
# URL della pagina MAL dell'anime. Verifichiamo la presenza di null, l'unicità, che il format sia corretto e che ci sia coerenza tra `mal_id` e `url`.

# %%
df_details['url'] = df_details['url'].str.strip()
analyze(df_details['url'])

pattern_url = r'^https://myanimelist\.net/anime/\d+/\S+$'
non_conformi_url = df_details[~df_details['url'].str.match(pattern_url, na=False)]
print(f'URL non conformi al formato atteso: {len(non_conformi_url)}')

# Consistenza mal_id <-> url
id_from_url = df_details['url'].str.extract(r'/anime/(\d+)/')[0].astype(int)
mismatch_url = id_from_url != df_details['mal_id']
print(f'mal_id non coerente con url        : {mismatch_url.sum()}')
# Out:
#   Nome serie                     url
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,955  (100.00%)
#   Null / NaN                     0  (0.00%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   28,955  (100.00%)
#   Valori duplicati               0  (0.00%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  35  caratteri
#   Lunghezza max                  216  caratteri
#   Lunghezza media                60.19  caratteri
#   Lunghezza mediana              57.0000  caratteri
#   Dev. standard lunghezza        14.92
#   IQR lunghezza                  17.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ───────────────────────────────────────────────────
#    #1         216   https://myanimelist.net/anime/60303/Shinjiteita_Na…
#    #2         173   https://myanimelist.net/anime/62002/99-kai_Danzai_…
#    #3         172   https://myanimelist.net/anime/61127/Shoukan_Showca…
#    #4         166   https://myanimelist.net/anime/57005/Mukuwarenakatt…
#    #5         166   https://myanimelist.net/anime/61271/NEET_Kunoichi_…
#    #6         165   https://myanimelist.net/anime/60140/Kanchigai_no_A…
#    #7         162   https://myanimelist.net/anime/36596/Watashi_no_Nak…
#    #8         158   https://myanimelist.net/anime/33879/Kochira_Katsus…
#    #9         154   https://myanimelist.net/anime/33876/Kochira_Katsus…
#   #10         154   https://myanimelist.net/anime/56736/Saikyou_Degara…
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ─────────────────────────────────────
#    #1          35   https://myanimelist.net/anime/156/X
#    #2          36   https://myanimelist.net/anime/6055/F
#    #3          36   https://myanimelist.net/anime/386/H2
#    #4          37   https://myanimelist.net/anime/56036/-
#    #5          37   https://myanimelist.net/anime/38756/2
#    #6          37   https://myanimelist.net/anime/36089/9
#    #7          37   https://myanimelist.net/anime/4934/AF
#    #8          37   https://myanimelist.net/anime/6535/Ai
#    #9          37   https://myanimelist.net/anime/101/Air
#   #10          37   https://myanimelist.net/anime/31687/◯
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   35 – 44                             2,571     8.9%
#   44 – 53                             9,088    31.4%
#   53 – 62                             7,155    24.7%
#   62 – 71                             4,774    16.5%
#   71 – 80                             2,536     8.8%
#   80 – 89                             1,392     4.8%
#   89 – 98                               778     2.7%
#   98 – 107                              329     1.1%
#   107 – 116                             174     0.6%
#   116 – 125                              77     0.3%
#   125 – 134                              37     0.1%
#   134 – 143                              22     0.1%
#   143 – 152                              11     0.0%
#   152 – 161                               4     0.0%
#   161 – 170                               4     0.0%
#   170 – 179                               2     0.0%
#   179 – 188                               0     0.0%
#   188 – 197                               0     0.0%
#   197 – 206                               0     0.0%
#   206 – 216                               1     0.0%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore                                                Conteggio      %
#   ───────────────────────────────────────────────────   ─────────   ────
#   https://myanimelist.net/anime/59356/-Socket-                  1   0.0%
#   https://myanimelist.net/anime/56036/-                         1   0.0%
#   https://myanimelist.net/anime/2928/hack__GU_Return…           1   0.0%
#   https://myanimelist.net/anime/3269/hack__GU_Trilog…           1   0.0%
#   https://myanimelist.net/anime/4469/hack__GU_Trilog…           1   0.0%
#   https://myanimelist.net/anime/454/hack__Gift                  1   0.0%
#   https://myanimelist.net/anime/1143/hack__Intermezz…           1   0.0%
#   https://myanimelist.net/anime/299/hack__Liminality            1   0.0%
#   https://myanimelist.net/anime/9332/hack__Quantum              1   0.0%
#   https://myanimelist.net/anime/10390/hack__Quantum_…           1   0.0%
#
#   I 10 meno frequenti (più rari):
#   Valore                                                Conteggio      %
#   ───────────────────────────────────────────────────   ─────────   ────
#   https://myanimelist.net/anime/56606/Zutto_Tomodach…           1   0.0%
#   https://myanimelist.net/anime/34895/Zutto_Suki_Dat…           1   0.0%
#   https://myanimelist.net/anime/36305/Zutto_Mae_kara…           1   0.0%
#   https://myanimelist.net/anime/31245/Zutto_Mae_kara…           1   0.0%
#   https://myanimelist.net/anime/59421/Zutaboro_Reijo…           1   0.0%
#   https://myanimelist.net/anime/58303/Zurukute_Sugoi            1   0.0%
#   https://myanimelist.net/anime/52512/Zurui_Maborosh…           1   0.0%
#   https://myanimelist.net/anime/45069/Zuqiu_Wangzhe             1   0.0%
#   https://myanimelist.net/anime/45187/Zuqiu_Jianghu             1   0.0%
#   https://myanimelist.net/anime/46436/Zuoyou_Nao_Zhi…           1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 28,955  (100.0%)
#   Contiene maiuscole             28,915  (99.9%)
#   Contiene minuscole             28,955  (100.0%)
#   Contiene spazi                 0  (0.0%)
#   Contiene caratteri speciali    28,955  (100.0%)
#   Contiene URL                   28,955  (100.0%)
#   Contiene @                     0  (0.0%)
#   Solo numerico                  0
#   Solo alfabetico                0
#   Solo alfanumerico              0
#
# URL non conformi al formato atteso: 0
# mal_id non coerente con url        : 0

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 28.955 record hanno un URL valido.
# - **Nessun duplicato**: coerente con `mal_id` come chiave primaria.
# - Tutti i 28.955 URL seguono il pattern `https://myanimelist.net/anime/{id}/...`. Nessuna anomalia.
# - L'ID estratto dall'URL corrisponde esattamente a `mal_id` per ogni riga. Nessuna inconsistenza.
#
# **Nessuna pulizia necessaria.**

# %% [markdown]
# ### 2.5 `image_url`
#
# URL dell'immagine di copertina. Verifichiamo anche il format del URL.

# %%
df_details['image_url'] = df_details['image_url'].str.strip()
analyze(df_details['image_url'])

pattern_img = r'^https://cdn\.myanimelist\.net/(images/anime/\d+/\d+\.(jpg|webp|png)|img/sp/icon/apple-touch-icon-256\.png)$'
non_conformi_img = df_details[~df_details['image_url'].str.match(pattern_img, na=False)]
print(f'image_url non conformi al formato atteso: {len(non_conformi_img)}')
# Out:
#   Nome serie                     image_url
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,955  (100.00%)
#   Null / NaN                     0  (0.00%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   28,758  (99.32%)
#   Valori duplicati               197  (0.68%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  50  caratteri
#   Lunghezza max                  64  caratteri
#   Lunghezza media                54.69  caratteri
#   Lunghezza mediana              56.0000  caratteri
#   Dev. standard lunghezza        1.93
#   IQR lunghezza                  3.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ───────────────────────────────────────────────────
#    #1          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #2          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #3          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #4          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #5          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #6          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #7          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #8          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#    #9          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#   #10          64   https://cdn.myanimelist.net/img/sp/icon/apple-touc…
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────────────────────────────────────────────────
#    #1          50   https://cdn.myanimelist.net/images/anime/1/303.jpg
#    #2          50   https://cdn.myanimelist.net/images/anime/1/740.jpg
#    #3          50   https://cdn.myanimelist.net/images/anime/1/834.jpg
#    #4          50   https://cdn.myanimelist.net/images/anime/1/317.jpg
#    #5          50   https://cdn.myanimelist.net/images/anime/1/139.jpg
#    #6          50   https://cdn.myanimelist.net/images/anime/1/137.jpg
#    #7          50   https://cdn.myanimelist.net/images/anime/1/359.jpg
#    #8          50   https://cdn.myanimelist.net/images/anime/1/864.jpg
#    #9          50   https://cdn.myanimelist.net/images/anime/1/766.jpg
#   #10          50   https://cdn.myanimelist.net/images/anime/1/952.jpg
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   50 – 50                                19     0.1%
#   50 – 51                               372     1.3%
#   51 – 52                             6,498    22.4%
#   52 – 53                             3,171    11.0%
#   53 – 54                                 0     0.0%
#   54 – 55                             2,069     7.1%
#   55 – 56                            16,628    57.4%
#   56 – 57                                 0     0.0%
#   57 – 58                                 0     0.0%
#   58 – 59                                 0     0.0%
#   59 – 60                                 0     0.0%
#   60 – 61                                 0     0.0%
#   61 – 62                                 0     0.0%
#   62 – 63                                 0     0.0%
#   63 – 64                               198     0.7%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore                                                Conteggio      %
#   ───────────────────────────────────────────────────   ─────────   ────
#   https://cdn.myanimelist.net/img/sp/icon/apple-touc…         198   0.7%
#   https://cdn.myanimelist.net/images/anime/1043/1443…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1057/1372…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1798/1159…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1566/1510…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/10/8661.j…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/2/23085.j…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1844/1315…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/7/23079.j…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1894/1488…           1   0.0%
#
#   I 10 meno frequenti (più rari):
#   Valore                                                Conteggio      %
#   ───────────────────────────────────────────────────   ─────────   ────
#   https://cdn.myanimelist.net/images/anime/1462/1383…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1498/1043…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/6/88310.j…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/3/82121.j…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1518/1499…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1782/1419…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1096/1263…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1697/1281…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1281/1290…           1   0.0%
#   https://cdn.myanimelist.net/images/anime/1043/1302…           1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 28,955  (100.0%)
#   Contiene maiuscole             0  (0.0%)
#   Contiene minuscole             28,955  (100.0%)
#   Contiene spazi                 0  (0.0%)
#   Contiene caratteri speciali    28,955  (100.0%)
#   Contiene URL                   28,955  (100.0%)
#   Contiene @                     0  (0.0%)
#   Solo numerico                  0
#   Solo alfabetico                0
#   Solo alfanumerico              0
#
# image_url non conformi al formato atteso: 0

# %% [markdown]
# **Osservazione**
# - Non ci sono stringhe vuote o null. Tutta la colonna è popolata.
# - Tutti i 28.955 URL seguono il pattern corretto
# - Ci sono 197 URL duplicati che corrispondono a un link che porta a un'immagine placeholder. A ogni personaggio senza immagine reale viene assegnato il logo MAL. Non è un errore e non è necessaria nessuna pulizia.
# - Tutte le URL seguono il formato corretto senza nessuna anomalia strutturale.
#
# **Nessuna pulizia necessaria**

# %% [markdown]
# ### 2.6 `type`
#
# Colonna categorica con il tipo di anime (TV, Movie, OVA, ONA, Special, Music, CM, PV, TV Special).

# %%
df_details['type'] = df_details['type'].str.strip()
analyze(df_details['type'])
# Out:
#   Nome serie                     type
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,888  (99.77%)
#   Null / NaN                     67  (0.23%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   9  (0.03%)
#   Valori duplicati               28,879  (99.74%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  2  caratteri
#   Lunghezza max                  10  caratteri
#   Lunghezza media                3.73  caratteri
#   Lunghezza mediana              3.0000  caratteri
#   Dev. standard lunghezza        1.81
#   IQR lunghezza                  3.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────────
#    #1          10   TV Special
#    #2          10   TV Special
#    #3          10   TV Special
#    #4          10   TV Special
#    #5          10   TV Special
#    #6          10   TV Special
#    #7          10   TV Special
#    #8          10   TV Special
#    #9          10   TV Special
#   #10          10   TV Special
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────
#    #1           2   TV
#    #2           2   TV
#    #3           2   TV
#    #4           2   TV
#    #5           2   TV
#    #6           2   TV
#    #7           2   CM
#    #8           2   TV
#    #9           2   TV
#   #10           2   TV
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   2 – 2                               9,172    31.8%
#   2 – 3                               8,280    28.7%
#   3 – 4                                   0     0.0%
#   4 – 5                               8,914    30.9%
#   5 – 6                                   0     0.0%
#   6 – 7                               1,755     6.1%
#   7 – 8                                   0     0.0%
#   8 – 9                                   0     0.0%
#   9 – 10                                767     2.7%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore       Conteggio       %
#   ──────────   ─────────   ─────
#   TV               8,414   29.1%
#   Movie            4,915   17.0%
#   OVA              4,184   14.5%
#   ONA              4,096   14.2%
#   Music            3,999   13.8%
#   Special          1,755    6.1%
#   TV Special         767    2.7%
#   CM                 483    1.7%
#   PV                 275    1.0%
#
#   I 10 meno frequenti (più rari):
#   Valore       Conteggio       %
#   ──────────   ─────────   ─────
#   PV                 275    1.0%
#   CM                 483    1.7%
#   TV Special         767    2.7%
#   Special          1,755    6.1%
#   Music            3,999   13.8%
#   ONA              4,096   14.2%
#   OVA              4,184   14.5%
#   Movie            4,915   17.0%
#   TV               8,414   29.1%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 0  (0.0%)
#   Contiene maiuscole             28,888  (100.0%)
#   Contiene minuscole             11,436  (39.6%)
#   Contiene spazi                 767  (2.7%)
#   Contiene caratteri speciali    0  (0.0%)
#   Contiene URL                   0  (0.0%)
#   Contiene @                     0  (0.0%)
#   Solo numerico                  0
#   Solo alfabetico                28,121
#   Solo alfanumerico              28,121

# %% [markdown]
# **Osservazioni:**
# - **67 valori nulli**: attesi, anime ancora non publicate per cui il tipo non è ancora registrato su MAL.
# - **9 valori distinti**: tutti coerenti con la terminologia MAL (TV, Movie, OVA, ONA, Special, Music, CM, PV, TV Special).
#
# **Nessuna pulizia necessaria.**

# %% [markdown]
# ### 2.7 `status`
#
# Colonna categorica con lo stato di trasmissione.

# %%
df_details['status'] = df_details['status'].str.strip()
analyze(df_details['status'])
# Out:
#   Nome serie                     status
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,955  (100.00%)
#   Null / NaN                     0  (0.00%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   3  (0.01%)
#   Valori duplicati               28,952  (99.99%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  13  caratteri
#   Lunghezza max                  16  caratteri
#   Lunghezza media                14.97  caratteri
#   Lunghezza mediana              15.0000  caratteri
#   Dev. standard lunghezza        0.29
#   IQR lunghezza                  0.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ────────────────
#    #1          16   Currently Airing
#    #2          16   Currently Airing
#    #3          16   Currently Airing
#    #4          16   Currently Airing
#    #5          16   Currently Airing
#    #6          16   Currently Airing
#    #7          16   Currently Airing
#    #8          16   Currently Airing
#    #9          16   Currently Airing
#   #10          16   Currently Airing
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ─────────────
#    #1          13   Not yet aired
#    #2          13   Not yet aired
#    #3          13   Not yet aired
#    #4          13   Not yet aired
#    #5          13   Not yet aired
#    #6          13   Not yet aired
#    #7          13   Not yet aired
#    #8          13   Not yet aired
#    #9          13   Not yet aired
#   #10          13   Not yet aired
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   13 – 13                               544     1.9%
#   13 – 14                                 0     0.0%
#   14 – 15                            28,097    97.0%
#   15 – 16                               314     1.1%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore             Conteggio       %
#   ────────────────   ─────────   ─────
#   Finished Airing       28,097   97.0%
#   Not yet aired            544    1.9%
#   Currently Airing         314    1.1%
#
#   I 10 meno frequenti (più rari):
#   Valore             Conteggio       %
#   ────────────────   ─────────   ─────
#   Currently Airing         314    1.1%
#   Not yet aired            544    1.9%
#   Finished Airing       28,097   97.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 0  (0.0%)
#   Contiene maiuscole             28,955  (100.0%)
#   Contiene minuscole             28,955  (100.0%)
#   Contiene spazi                 28,955  (100.0%)
#   Contiene caratteri speciali    0  (0.0%)
#   Contiene URL                   0  (0.0%)
#   Contiene @                     0  (0.0%)
#   Solo numerico                  0
#   Solo alfabetico                0
#   Solo alfanumerico              0
#
# Analisi parole / token
# ────────────────────────────────────────────────────────────────────────────────
#
#   Parole medie per valore        2.02
#   Max parole                     3
#   Min parole                     2
#
#   Le 10 parole più comuni:
#   Parola                  Conteggio
#   ────────────────────   ──────────
#   Airing                     28,411
#   Finished                   28,097
#   Not                           544
#   yet                           544
#   aired                         544
#   Currently                     314

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 28.955 record hanno uno stato definito.
# - **3 valori distinti**: `Finished Airing`, `Currently Airing`, `Not yet aired`, coerenti con la terminologia MAL.
#
# **Nessuna pulizia necessaria.**

# %% [markdown]
# ### 2.8 `score`
#
# Punteggio medio assegnato dagli utenti MAL.

# %%
analyze(df_details['score'])
# Out:
#   Nome serie                     score
#   dtype                          float64
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           NUMERICO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               18,882  (65.21%)
#   Null / NaN                     10,073  (34.79%)
#   Zeri                           0  (0.00%)
#   Positivi                       18,882   (65.21%)
#   Negativi                       0   (0.00%)
#   Valori unici                   561  (1.94%)
#   Valori float                   18,737
#
# Statistiche descrittive
# ────────────────────────────────────────────────────────────────────────────────
#
#   Min                            1.8900
#   Max                            9.2900
#   Range                          7.4000
#   Media                          6.3905
#   Mediana                        6.3600
#   Moda/e                         6.2900
#   Dev. standard                  0.8920
#   Varianza                       0.7957
#   Errore std (SEM)               0.0065
#   IQR  (Q3 − Q1)                 1.2600
#   Q1  (25° pct)                  5.7700
#   Q3  (75° pct)                  7.0300
#   P5  ( 5° pct)                  4.9900
#   P95 (95° pct)                  7.8700
#   Coefficiente di variazione     13.96%
#
# Analisi outlier
# ────────────────────────────────────────────────────────────────────────────────
#
#   Soglia bassa  (Q1 − 1.5×IQR)   3.8800
#   Soglia alta   (Q3 + 1.5×IQR)   8.9200
#   Outlier rilevati               102  (0.35%)
#
#   Top 5 outlier estremi (per valore assoluto):
#     [23116]  9.2900
#     [6593]  9.1000
#     [23288]  9.0700
#     [7379]  9.0500
#     [7383]  9.0500
#
# Distribuzione
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   1 – 2                                   3     0.0%
#   2 – 2                                   4     0.0%
#   2 – 3                                   8     0.0%
#   3 – 3                                  20     0.1%
#   3 – 3                                  26     0.1%
#   3 – 4                                  50     0.3%
#   4 – 4                                 123     0.7%
#   4 – 4                                 451     2.4%
#   4 – 5                                 886     4.7%
#   5 – 5                               1,890    10.0%
#   5 – 5                               2,647    14.0%
#   5 – 6                               2,991    15.8%
#   6 – 6                               3,010    15.9%
#   6 – 7                               2,275    12.0%
#   7 – 7                               2,133    11.3%
#   7 – 7                               1,280     6.8%
#   7 – 8                                 629     3.3%
#   8 – 8                                 326     1.7%
#   8 – 8                                 111     0.6%
#   8 – 9                                  19     0.1%
#
# Valori estremi
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più grandi:
#     #1   9.2900
#     #2   9.1000
#     #3   9.0700
#     #4   9.0500
#     #5   9.0500
#     #6   9.0500
#     #7   9.0300
#     #8   9.0300
#     #9   9.0200
#     #10  9.0200
#
#   I 10 più piccoli:
#     #1   1.8900
#     #2   2.0100
#     #3   2.2300
#     #4   2.3300
#     #5   2.4100
#     #6   2.4300
#     #7   2.5600
#     #8   2.6800
#     #9   2.6800
#     #10  2.7500
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#                 Valore    Conteggio        %
#   ────────────────────   ──────────   ──────
#                 6.2900          102     0.4%
#                 6.3300          100     0.3%
#                 6.5300           99     0.3%
#                 6.5100           98     0.3%
#                 6.2100           97     0.3%
#                 6.4600           95     0.3%
#                 6.0600           95     0.3%
#                 6.4100           95     0.3%
#                 5.9800           94     0.3%
#                 6.4400           93     0.3%
#
#   I 10 meno frequenti:
#                 Valore    Conteggio        %
#   ────────────────────   ──────────   ──────
#                 3.5300            1     0.0%
#                 4.0000            1     0.0%
#                 3.4800            1     0.0%
#                 3.6400            1     0.0%
#                 8.8400            1     0.0%
#                 8.8200            1     0.0%
#                 3.3300            1     0.0%
#                 2.0100            1     0.0%
#                 2.3300            1     0.0%
#                 1.8900            1     0.0%

# %% [markdown]
# **Osservazioni:**
# - **10.073 valori nulli** (~34.8%): in quanto la valutazione va da 1 a 10, un valore null rapresenta l'assenza di valutazioni.
# - Il dtype `float64` corretto. Nessuna conversione necessaria.
# - Gli outliers non vengono considerati in quanto una valutazione compresa tra 1 e 10 non è un errore.
#
# **Nessuna pulizia necessaria**.

# %% [markdown]
# ### 2.9 `scored_by`
#
# Numero di utenti che hanno votato.

# %%
analyze(df_details['scored_by'])
# Out:
#   Nome serie                     scored_by
#   dtype                          float64
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           NUMERICO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               18,882  (65.21%)
#   Null / NaN                     10,073  (34.79%)
#   Zeri                           0  (0.00%)
#   Positivi                       18,882   (65.21%)
#   Negativi                       0   (0.00%)
#   Valori unici                   9,245  (31.93%)
#   Valori float                   0
#
# Statistiche descrittive
# ────────────────────────────────────────────────────────────────────────────────
#
#   Min                            101.0000
#   Max                            2,979,733
#   Range                          2,979,632
#   Media                          29,963.08
#   Mediana                        1,528.00
#   Moda/e                         120.0000
#   Dev. standard                  121,966.56
#   Varianza                       14,875,842,969
#   Errore std (SEM)               887.5990
#   IQR  (Q3 − Q1)                 9,813.50
#   Q1  (25° pct)                  332.2500
#   Q3  (75° pct)                  10,145.75
#   P5  ( 5° pct)                  134.0000
#   P95 (95° pct)                  138,467.35
#   Coefficiente di variazione     407.06%
#
# Analisi outlier
# ────────────────────────────────────────────────────────────────────────────────
#
#   Soglia bassa  (Q1 − 1.5×IQR)   -14,388.00
#   Soglia alta   (Q3 + 1.5×IQR)   24,866.00
#   Outlier rilevati               3,150  (10.88%)
#
#   Top 5 outlier estremi (per valore assoluto):
#     [22010]  2,979,733
#     [4788]  2,919,353
#     [17990]  2,365,396
#     [12300]  2,281,401
#     [6593]  2,248,907
#
# Distribuzione
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   101 – 149,082                      18,019    95.4%
#   149,082 – 298,064                     452     2.4%
#   298,064 – 447,045                     160     0.8%
#   447,045 – 596,027                      82     0.4%
#   596,027 – 745,009                      52     0.3%
#   745,009 – 893,990                      26     0.1%
#   893,990 – 1,042,972                    28     0.1%
#   1,042,972 – 1,191,953                  17     0.1%
#   1,191,953 – 1,340,935                  11     0.1%
#   1,340,935 – 1,489,917                  14     0.1%
#   1,489,917 – 1,638,898                   3     0.0%
#   1,638,898 – 1,787,880                   4     0.0%
#   1,787,880 – 1,936,861                   3     0.0%
#   1,936,861 – 2,085,843                   3     0.0%
#   2,085,843 – 2,234,825                   2     0.0%
#   2,234,825 – 2,383,806                   4     0.0%
#   2,383,806 – 2,532,788                   0     0.0%
#   2,532,788 – 2,681,769                   0     0.0%
#   2,681,769 – 2,830,751                   0     0.0%
#   2,830,751 – 2,979,733                   2     0.0%
#
# Valori estremi
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più grandi:
#     #1   2,979,733
#     #2   2,919,353
#     #3   2,365,396
#     #4   2,281,401
#     #5   2,248,907
#     #6   2,240,438
#     #7   2,181,208
#     #8   2,088,445
#     #9   2,027,815
#     #10  2,003,062
#
#   I 10 più piccoli:
#     #1   101.0000
#     #2   101.0000
#     #3   101.0000
#     #4   102.0000
#     #5   102.0000
#     #6   102.0000
#     #7   102.0000
#     #8   102.0000
#     #9   103.0000
#     #10  103.0000
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#                 Valore    Conteggio        %
#   ────────────────────   ──────────   ──────
#               120.0000           46     0.2%
#               121.0000           44     0.2%
#               117.0000           42     0.1%
#               111.0000           41     0.1%
#               127.0000           40     0.1%
#               132.0000           40     0.1%
#               143.0000           39     0.1%
#               151.0000           39     0.1%
#               135.0000           39     0.1%
#               133.0000           38     0.1%
#
#   I 10 meno frequenti:
#                 Valore    Conteggio        %
#   ────────────────────   ──────────   ──────
#               1,887.00            1     0.0%
#              10,038.00            1     0.0%
#             104,106.00            1     0.0%
#              15,624.00            1     0.0%
#               2,219.00            1     0.0%
#              14,906.00            1     0.0%
#               4,192.00            1     0.0%
#              94,201.00            1     0.0%
#             250,375.00            1     0.0%
#              65,863.00            1     0.0%

# %% [markdown]
# **Osservazioni:**
# - **10.073 valori nulli** che corrispondono allo stesso numero di valori null della colonna `score`. Verifichiamo che si tratti delle stesse righe.
# - Il dtype `float64`. Lo convertiamo a `Int64`.
# - Gli outlier rilevati sono anime famosi con alta partecipazione, non errori nei dati.

# %%
# Verifica co-nullità
print(f'Null in score     : {df_details["score"].isna().sum():,}')
print(f'Null in scored_by : {df_details["scored_by"].isna().sum():,}')
print(f'Co-nulli (entrambi NaN) : {(df_details["score"].isna() & df_details["scored_by"].isna()).sum():,}')
print()

#Convertiamo a int
df_details['scored_by'] = df_details['scored_by'].astype('Int64')
print(f'scored_by dtype : {df_details["scored_by"].dtype}')
# Out:
# Null in score     : 10,073
# Null in scored_by : 10,073
# Co-nulli (entrambi NaN) : 10,073
#
# scored_by dtype : Int64

# %% [markdown]
# Si verifica che i valori null su `scored_by` corrispondono ai valori null su `scored`.
#
# **Nessuna pulizia necessaria**.

# %% [markdown]
# ### 2.10 `start_date`
#
# Data di inizio trasmissione, memorizzata come stringa. Usiamo `analyze` per capire il formato e valutare la conversione in un tipo datetime. I null sono attesi per gli anime `Not yet aired` senza data confermata.

# %%
df_details['start_date'] = df_details['start_date'].str.strip()
analyze(df_details['start_date'])
# Out:
#   Nome serie                     start_date
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               28,104  (97.06%)
#   Null / NaN                     851  (2.94%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   9,367  (32.35%)
#   Valori duplicati               18,737  (64.71%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  25  caratteri
#   Lunghezza max                  25  caratteri
#   Lunghezza media                25.00  caratteri
#   Lunghezza mediana              25.0000  caratteri
#   Dev. standard lunghezza        0.00
#   IQR lunghezza                  0.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ─────────────────────────
#    #1          25   2010-01-01T00:00:00+00:00
#    #2          25   2023-06-11T00:00:00+00:00
#    #3          25   2007-01-18T00:00:00+00:00
#    #4          25   2007-12-22T00:00:00+00:00
#    #5          25   2008-03-25T00:00:00+00:00
#    #6          25   2003-11-16T00:00:00+00:00
#    #7          25   2003-03-28T00:00:00+00:00
#    #8          25   2002-06-20T00:00:00+00:00
#    #9          25   2011-01-28T00:00:00+00:00
#   #10          25   2011-01-28T00:00:00+00:00
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ─────────────────────────
#    #1          25   2010-01-01T00:00:00+00:00
#    #2          25   2023-06-11T00:00:00+00:00
#    #3          25   2007-01-18T00:00:00+00:00
#    #4          25   2007-12-22T00:00:00+00:00
#    #5          25   2008-03-25T00:00:00+00:00
#    #6          25   2003-11-16T00:00:00+00:00
#    #7          25   2003-03-28T00:00:00+00:00
#    #8          25   2002-06-20T00:00:00+00:00
#    #9          25   2011-01-28T00:00:00+00:00
#   #10          25   2011-01-28T00:00:00+00:00
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Tutte le stringhe hanno la stessa lunghezza. (25 caratteri)
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore                      Conteggio      %
#   ─────────────────────────   ─────────   ────
#   2012-01-01T00:00:00+00:00         158   0.6%
#   2011-01-01T00:00:00+00:00         153   0.5%
#   2019-01-01T00:00:00+00:00         146   0.5%
#   2010-01-01T00:00:00+00:00         145   0.5%
#   2026-01-01T00:00:00+00:00         133   0.5%
#   2015-01-01T00:00:00+00:00         125   0.4%
#   2013-01-01T00:00:00+00:00         122   0.4%
#   2008-01-01T00:00:00+00:00         114   0.4%
#   2009-01-01T00:00:00+00:00         110   0.4%
#   2014-01-01T00:00:00+00:00         109   0.4%
#
#   I 10 meno frequenti (più rari):
#   Valore                      Conteggio      %
#   ─────────────────────────   ─────────   ────
#   2019-08-17T00:00:00+00:00           1   0.0%
#   1995-11-11T00:00:00+00:00           1   0.0%
#   1980-04-15T00:00:00+00:00           1   0.0%
#   1992-07-04T00:00:00+00:00           1   0.0%
#   2015-12-08T00:00:00+00:00           1   0.0%
#   2011-05-18T00:00:00+00:00           1   0.0%
#   2014-05-21T00:00:00+00:00           1   0.0%
#   2009-02-27T00:00:00+00:00           1   0.0%
#   2019-05-19T00:00:00+00:00           1   0.0%
#   2020-10-17T00:00:00+00:00           1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 28,104  (100.0%)
#   Contiene maiuscole             28,104  (100.0%)
#   Contiene minuscole             0  (0.0%)
#   Contiene spazi                 0  (0.0%)
#   Contiene caratteri speciali    28,104  (100.0%)
#   Contiene URL                   0  (0.0%)
#   Contiene @                     0  (0.0%)
#   Solo numerico                  0
#   Solo alfabetico                0
#   Solo alfanumerico              0

# %% [markdown]
# **Osservazioni:**
# - **851 valori nulli** (~2.9%): strutturali, anime `Not yet aired` senza data confermata.
# - **Lunghezza costante di 25 caratteri** e tutti gli esempi mostrano il pattern `YYYY-MM-DDTHH:MM:SS+00:00` con offset `+00:00` che rapresenta il timezone.
# - **Conversione necessaria**: da stringa a `datetime64[us, UTC]` per abilitare operazioni temporali (confronti, differenze, etc). Usiamo UTC perché è la scelta coerente con l'offset `+00:00` già presente nei dati.
# **Nessuna ulteriore pulizia necessaria.**

# %%
df_details['start_date'] = pd.to_datetime(df_details['start_date'], errors='coerce', utc=True)
print(f'start_date dtype: {df_details["start_date"].dtype}')
# Out:
# start_date dtype: datetime64[us, UTC]

# %% [markdown]
# ### 2.11 `end_date`
#
# Data di fine trasmissione, stessa struttura di `start_date`. I null sono più numerosi: gli anime `Currently Airing` e `Not yet aired` non hanno ancora una data di fine.

# %%
df_details['end_date'] = df_details['end_date'].str.strip()
analyze(df_details['end_date'])
# Out:
#   Nome serie                     end_date
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               11,267  (38.91%)
#   Null / NaN                     17,688  (61.09%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   5,607  (19.36%)
#   Valori duplicati               5,660  (19.55%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  25  caratteri
#   Lunghezza max                  25  caratteri
#   Lunghezza media                25.00  caratteri
#   Lunghezza mediana              25.0000  caratteri
#   Dev. standard lunghezza        0.00
#   IQR lunghezza                  0.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ─────────────────────────
#    #1          25   2003-04-10T00:00:00+00:00
#    #2          25   2011-04-07T00:00:00+00:00
#    #3          25   2011-04-07T00:00:00+00:00
#    #4          25   2006-09-28T00:00:00+00:00
#    #5          25   2002-09-26T00:00:00+00:00
#    #6          25   2003-03-27T00:00:00+00:00
#    #7          25   2018-12-28T00:00:00+00:00
#    #8          25   2024-09-22T00:00:00+00:00
#    #9          25   2025-03-23T00:00:00+00:00
#   #10          25   1964-10-27T00:00:00+00:00
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ─────────────────────────
#    #1          25   2003-04-10T00:00:00+00:00
#    #2          25   2011-04-07T00:00:00+00:00
#    #3          25   2011-04-07T00:00:00+00:00
#    #4          25   2006-09-28T00:00:00+00:00
#    #5          25   2002-09-26T00:00:00+00:00
#    #6          25   2003-03-27T00:00:00+00:00
#    #7          25   2018-12-28T00:00:00+00:00
#    #8          25   2024-09-22T00:00:00+00:00
#    #9          25   2025-03-23T00:00:00+00:00
#   #10          25   1964-10-27T00:00:00+00:00
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Tutte le stringhe hanno la stessa lunghezza. (25 caratteri)
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore                      Conteggio      %
#   ─────────────────────────   ─────────   ────
#   2013-01-01T00:00:00+00:00          21   0.2%
#   2019-01-01T00:00:00+00:00          18   0.2%
#   2012-01-01T00:00:00+00:00          18   0.2%
#   2014-01-01T00:00:00+00:00          17   0.2%
#   2023-03-26T00:00:00+00:00          17   0.2%
#   2008-01-01T00:00:00+00:00          15   0.1%
#   2016-03-25T00:00:00+00:00          14   0.1%
#   2011-01-01T00:00:00+00:00          14   0.1%
#   2017-01-01T00:00:00+00:00          14   0.1%
#   2016-03-26T00:00:00+00:00          14   0.1%
#
#   I 10 meno frequenti (più rari):
#   Valore                      Conteggio      %
#   ─────────────────────────   ─────────   ────
#   2017-11-22T00:00:00+00:00           1   0.0%
#   1980-09-23T00:00:00+00:00           1   0.0%
#   2020-07-22T00:00:00+00:00           1   0.0%
#   2025-07-05T00:00:00+00:00           1   0.0%
#   2011-11-16T00:00:00+00:00           1   0.0%
#   2007-09-12T00:00:00+00:00           1   0.0%
#   2016-07-23T00:00:00+00:00           1   0.0%
#   2021-11-19T00:00:00+00:00           1   0.0%
#   2009-03-31T00:00:00+00:00           1   0.0%
#   2001-04-25T00:00:00+00:00           1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 11,267  (100.0%)
#   Contiene maiuscole             11,267  (100.0%)
#   Contiene minuscole             0  (0.0%)
#   Contiene spazi                 0  (0.0%)
#   Contiene caratteri speciali    11,267  (100.0%)
#   Contiene URL                   0  (0.0%)
#   Contiene @                     0  (0.0%)
#   Solo numerico                  0
#   Solo alfabetico                0
#   Solo alfanumerico              0

# %% [markdown]
# **Osservazioni:**
# - **17.688 valori nulli** (~61.1%): strutturali, anime ancora in corso o non ancora iniziati.
# - Il format è lo stesso di `start_date`. Facciamo la conversione a `datetime64[us, UTC]`.

# %%
df_details['end_date'] = pd.to_datetime(df_details['end_date'], errors='coerce', utc=True)
print(f'end_date dtype: {df_details["end_date"].dtype}')
# Out:
# end_date dtype: datetime64[us, UTC]

# %% [markdown]
# **Verifica consistenza `start_date` ↔ `end_date`**
#
# Una volta convertite entrambe le date, verifichiamo che non ci siano righe in cui `end_date < start_date`: un anime non può terminare prima di iniziare. Consideriamo solo le righe in cui entrambe le date sono presenti, poiché confrontare con un valore nullo non ha significato.

# %%
# end_date < start_date
both_valid = df_details['start_date'].notna() & df_details['end_date'].notna()
inverted   = both_valid & (df_details['end_date'] < df_details['start_date'])
print(f'Righe con end_date < start_date: {inverted.sum()}')
print()
print(df_details[inverted][['mal_id', 'title', 'status', 'start_date', 'end_date']].head(10).to_string(index=False))
# Out:
# Righe con end_date < start_date: 101
#
#  mal_id                                     title          status                start_date                  end_date
#   48010                       23 Hao Niu Nai Tang Finished Airing 2020-03-01 00:00:00+00:00 2020-01-01 00:00:00+00:00
#   23583                    Akage no Anne Specials Finished Airing 2001-02-11 00:00:00+00:00 2001-01-01 00:00:00+00:00
#   44731                    Ali Diu Dongxi de Wawa Finished Airing 2012-08-31 00:00:00+00:00 2012-01-01 00:00:00+00:00
#   53727                         Ashuai 8th Season Finished Airing 2022-06-03 00:00:00+00:00 2022-01-01 00:00:00+00:00
#   45385                       AU: Kaixin Tongnian Finished Airing 2013-03-01 00:00:00+00:00 2013-01-01 00:00:00+00:00
#   10330 Bakugan Battle Brawlers: Mechtanium Surge Finished Airing 2018-09-01 00:00:00+00:00 2018-01-01 00:00:00+00:00
#   44551                       Baozou Kongbu Gushi Finished Airing 2014-07-11 00:00:00+00:00 2014-01-01 00:00:00+00:00
#   44555            Baozou Kongbu Gushi 5th Season Finished Airing 2017-02-07 00:00:00+00:00 2017-01-01 00:00:00+00:00
#   44557                                Baozou LOL Finished Airing 2015-01-25 00:00:00+00:00 2015-01-01 00:00:00+00:00
#   45723       Bodhi Yu Haoyou: Mengxiang Lianmeng Finished Airing 2017-01-16 00:00:00+00:00 2017-01-01 00:00:00+00:00

# %% [markdown]
# **Osservazioni:**
# - **101 righe** presentano `end_date < start_date`. Guardando i dati, il pattern è sempre lo stesso: `end_date` è il 1° gennaio di un anno (es. `2020-01-01`), mentre `start_date` è una data più tarda nello stesso anno (es. `2020-03-01`).
# - La spiegazione è che a volte quando si conosce solo l'**anno** di fine trasmissione, non il giorno esatto si registra automaticamente il 1° gennaio come data di fine. Il risultato è che la data di fine appare prima della data di inizio, ma non è un errore reale, è solo una mancanza di precisione nel dato originale. Facciamo una ulteriore verifica per vedere se ci sono casi che rispettano questo pattern.

# %%
# Righe con end_date < start_date e end_date != 1° gennaio
both_valid = df_details['start_date'].notna() & df_details['end_date'].notna()
inverted   = both_valid & (df_details['end_date'] < df_details['start_date'])
not_jan1   = inverted & ~((df_details['end_date'].dt.month == 1) & (df_details['end_date'].dt.day == 1))
print(f'Righe con end_date < start_date e end_date != 1° gennaio: {not_jan1.sum()}')
print()
print(df_details[not_jan1][['mal_id', 'title', 'status', 'start_date', 'end_date']].to_string(index=False))
# Out:
# Righe con end_date < start_date e end_date != 1° gennaio: 8
#
#  mal_id                                         title          status                start_date                  end_date
#    3705                                Flashback Game Finished Airing 2001-10-18 00:00:00+00:00 2001-04-18 00:00:00+00:00
#   10995                          Ganbare!! Nattou-san Finished Airing 2011-07-02 00:00:00+00:00 2011-07-01 00:00:00+00:00
#   56892                     Kkomimanyeo Lara Season 2 Finished Airing 2023-10-14 00:00:00+00:00 2023-01-06 00:00:00+00:00
#   34234                          Ohayou! Kokekkou-san Finished Airing 2016-10-02 00:00:00+00:00 2016-09-17 00:00:00+00:00
#   43976                    Qi Jiguang Yingxiong Chuan Finished Airing 2012-06-01 00:00:00+00:00 2012-05-01 00:00:00+00:00
#   38571                           Tobidase! Dokan-kun Finished Airing 2011-10-26 00:00:00+00:00 2011-03-14 00:00:00+00:00
#   62453 Tobot: Daedosiui Yeongungdeul Season 2 Part 2 Finished Airing 2024-07-05 00:00:00+00:00 2023-08-23 00:00:00+00:00
#   61524                      Xiongmao He Gan Mi Xiong Finished Airing 2025-05-04 00:00:00+00:00 2025-04-08 00:00:00+00:00

# %% [markdown]
# Abbiamo effettuato una ricerca e risulta che per questi anime non si conosce la data esatta di fine trasmissione. Siccome si conosce solo l'anno, li normaliziamo per corrispondere al resto dove la data di fine è impostata a 01 Gennaio dello stesso anno. C'è un ecezzione dove l'anime `Tobot: Daedosiui Yeongungdeul Season 2 Part 2` sembra essere terminato 1 anno prima della data di rilascio. Abbiamo verificato che si tratta di un errore di battitura. Anche questo è terminato nello stesso anno.

# %%
both_valid = df_details['start_date'].notna() & df_details['end_date'].notna()
inverted   = both_valid & (df_details['end_date'] < df_details['start_date'])
not_jan1   = inverted & ~((df_details['end_date'].dt.month == 1) & (df_details['end_date'].dt.day == 1))

df_details.loc[not_jan1, 'end_date'] = df_details.loc[not_jan1, 'start_date'].apply(
    lambda dt: dt.replace(month=1, day=1)
)

print(f'end_date corrette: {not_jan1.sum()}')
print()
print(df_details.loc[not_jan1.index[not_jan1], ['mal_id', 'title', 'start_date', 'end_date']].to_string(index=False))
# Out:
# end_date corrette: 8
#
#  mal_id                                         title                start_date                  end_date
#    3705                                Flashback Game 2001-10-18 00:00:00+00:00 2001-01-01 00:00:00+00:00
#   10995                          Ganbare!! Nattou-san 2011-07-02 00:00:00+00:00 2011-01-01 00:00:00+00:00
#   56892                     Kkomimanyeo Lara Season 2 2023-10-14 00:00:00+00:00 2023-01-01 00:00:00+00:00
#   34234                          Ohayou! Kokekkou-san 2016-10-02 00:00:00+00:00 2016-01-01 00:00:00+00:00
#   43976                    Qi Jiguang Yingxiong Chuan 2012-06-01 00:00:00+00:00 2012-01-01 00:00:00+00:00
#   38571                           Tobidase! Dokan-kun 2011-10-26 00:00:00+00:00 2011-01-01 00:00:00+00:00
#   62453 Tobot: Daedosiui Yeongungdeul Season 2 Part 2 2024-07-05 00:00:00+00:00 2024-01-01 00:00:00+00:00
#   61524                      Xiongmao He Gan Mi Xiong 2025-05-04 00:00:00+00:00 2025-01-01 00:00:00+00:00

# %% [markdown]
# ### 2.12 `synopsis`
#
# Testo della sinossi dell'anime. I null sono attesi.

# %%
df_details['synopsis'] = df_details['synopsis'].str.strip()
analyze(df_details['synopsis'])
# Out:
#   Nome serie                     synopsis
#   dtype                          str
#   Dimensione                     28,955
#   Range indice                   0 … 28954
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   28,955
#   Valori non nulli               23,828  (82.29%)
#   Null / NaN                     5,127  (17.71%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   23,540  (81.30%)
#   Valori duplicati               288  (0.99%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  10  caratteri
#   Lunghezza max                  3,750  caratteri
#   Lunghezza media                377.40  caratteri
#   Lunghezza mediana              251.0000  caratteri
#   Dev. standard lunghezza        351.38
#   IQR lunghezza                  499.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ───────────────────────────────────────────────────
#    #1       3,750   Li Xiaobai, who entered the immersive stand-alone …
#    #2       3,635   Tezuka × Atobe ÷ Koharu↵ Fudomine Middle School's …
#    #3       3,268   One hundred thousand years ago, the immortal world…
#    #4       2,737   In In the year 2113 A.D., a team of scientists is …
#    #5       2,731   In the previous life, although Qin Yichen, the sag…
#    #6       2,633   The plot consists of a chase of a hijacked MBT-99A…
#    #7       2,615   This film consists of 6 animated shorts produced b…
#    #8       2,412   GOSHO collection reveals the origin of the smash h…
#    #9       2,410   Shouhei Zenya (The Night Before The Invitation)↵ P…
#   #10       2,315   Based on a seinen manga by Kikuchi Naoe and Yokomi…
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────────────
#    #1          10   G9+1 film.
#    #2          12   BD Specials.
#    #3          12   BD specials.
#    #4          12   DVD special.
#    #5          13   DVD/BD extra.
#    #6          13   Nurse hentai.
#    #7          13   DVD specials.
#    #8          13   DVD Specials.
#    #9          14   Chinpui movie.
#   #10          14   Second season.
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   10 – 197                           10,641    44.7%
#   197 – 384                           4,010    16.8%
#   384 – 571                           2,984    12.5%
#   571 – 758                           2,166     9.1%
#   758 – 945                           1,799     7.5%
#   945 – 1,132                         1,395     5.9%
#   1,132 – 1,319                         582     2.4%
#   1,319 – 1,506                         154     0.6%
#   1,506 – 1,693                          50     0.2%
#   1,693 – 1,880                          20     0.1%
#   1,880 – 2,067                          10     0.0%
#   2,067 – 2,254                           7     0.0%
#   2,254 – 2,441                           3     0.0%
#   2,441 – 2,628                           1     0.0%
#   2,628 – 2,815                           3     0.0%
#   2,815 – 3,002                           0     0.0%
#   3,002 – 3,189                           0     0.0%
#   3,189 – 3,376                           1     0.0%
#   3,376 – 3,563                           0     0.0%
#   3,563 – 3,750                           2     0.0%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore                                                Conteggio      %
#   ───────────────────────────────────────────────────   ─────────   ────
#   No synopsis has been added for this series yet.↵ ↵…          23   0.1%
#   Furukawa Taku film.                                          12   0.1%
#   Film by Takashi Ito.                                         12   0.1%
#   A short animation by Taku Furukawa.                          10   0.0%
#   A short film by Okamoto Tadanari.                             7   0.0%
#   Short animation by Rapparu.                                   6   0.0%
#   Short film by Hirano Ryou.                                    6   0.0%
#   A short puppet animation movie by Tadahito Mochina…           6   0.0%
#   Short film by Kurosaka Keita.                                 6   0.0%
#   A short film by Haruka Suzuki.                                5   0.0%
#
#   I 10 meno frequenti (più rari):
#   Valore                                                Conteggio      %
#   ───────────────────────────────────────────────────   ─────────   ────
#   Music video for the song Zutto Tomodachi by Keiko …           1   0.0%
#   Setsuna Shiraha has loved her childhood friend Gin…           1   0.0%
#   A picture drama special bundled with the BD/DVD re…           1   0.0%
#   Love is blooming at Sakuragaoka High School. Natsu…           1   0.0%
#   The Shaderan family has fallen on hard times, and …           1   0.0%
#   Music video for the song Zurukute Sugoi by THE BIN…           1   0.0%
#   Music video for the song Zurui Maboroshi, performe…           1   0.0%
#   The second season of Zuoshou Shanglan.                        1   0.0%
#   The story follows teenager Xu Xingze, a passionate…           1   0.0%
#   Zunko Tohoku can make any mochi into delicious zun…           1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 5,520  (23.2%)
#   Contiene maiuscole             23,826  (100.0%)
#   Contiene minuscole             23,828  (100.0%)
#   Contiene spazi                 23,828  (100.0%)
#   Contiene caratteri speciali    23,807  (99.9%)
#   Contiene URL                   3  (0.0%)
#   Contiene @                     38  (0.2%)
#   Solo numerico                  0
#   Solo alfabetico                0
#   Solo alfanumerico              0
#
# Analisi parole / token
# ────────────────────────────────────────────────────────────────────────────────
#
#   Parole medie per valore        63.48
#   Max parole                     638
#   Min parole                     2
#
#   Le 10 parole più comuni:
#   Parola                  Conteggio
#   ────────────────────   ──────────
#   the                        86,835
#   to                         43,834
#   of                         40,908
#   a                          40,351
#   and                        39,283
#   in                         20,100
#   is                         19,911
#   by                         16,286
#   his                        15,580
#   for                        13,106

# %% [markdown]
# **Osservazioni:**
# - **5.127 valori nulli** (~17.7%): strutturali, potrebbe trattarsi di cortometraggi, CM (Commercial Message) e PV (Promotional Video) che spesso non hanno una sinossi registrata.
# - **25 righe** contengono testo boilerplate di sistema (`"No synopsis has been added for this series yet."`): da convertire a `null`.
# - **288 valori duplicati**: da investigare, potrebbero nascondere ulteriori pattern boilerplate.
# - **3 sinossi contengono URL** e **38 contengono `@`**: da investigare per verificare che si tratti di contenuto legittimo.

# %% [markdown]
# **Duplicati nella sinossi:**
#
# `analyze()` riporta 288 valori duplicati. Esaminiamo i testi più ricorrenti per verificare se esistono altri pattern boilerplate non catturati dal filtro principale, oppure se si tratta di duplicati legittimi (sinossi condivise tra stagioni o titoli correlati).

# %%
# Duplicati in synopsis (su dati non ancora puliti)
dup_mask_syn = df_details['synopsis'].duplicated(keep=False) & df_details['synopsis'].notna()
dup_counts = df_details.loc[dup_mask_syn, 'synopsis'].value_counts()

print(f'Righe con synopsis duplicata: {dup_mask_syn.sum()}')
print(f'Testi univoci tra i duplicati: {len(dup_counts)}')
print()

top15 = dup_counts.head(15).reset_index()
top15.columns = ['synopsis', 'count']
top15['preview'] = top15['synopsis'].str[:120].str.replace('\n', ' ', regex=False).apply(repr)
top15['line'] = top15['count'].astype(str).str.rjust(3) + 'x  ' + top15['preview']

print('Top 15 synopsis duplicate (prime 120 caratteri):')
print('─' * 80)
print('\n'.join('  ' + top15['line']))
# Out:
# Righe con synopsis duplicata: 456
# Testi univoci tra i duplicati: 168
#
# Top 15 synopsis duplicate (prime 120 caratteri):
# ────────────────────────────────────────────────────────────────────────────────
#    23x  'No synopsis has been added for this series yet.  Click here to update this information.'
#    12x  'Furukawa Taku film.'
#    12x  'Film by Takashi Ito.'
#    10x  'A short animation by Taku Furukawa.'
#     7x  'A short film by Okamoto Tadanari.'
#     6x  'Short animation by Rapparu.'
#     6x  'Short film by Hirano Ryou.'
#     6x  'A short puppet animation movie by Tadahito Mochinaga.'
#     6x  'Short film by Kurosaka Keita.'
#     5x  'A short film by Haruka Suzuki.'
#     5x  'Unaired specials included in the Blu-ray and DVD release.'
#     4x  'A mix of animation and live-action.'
#     4x  'Three episodes aired on TV as part of the Ribon x Oha Suta specials.'
#     4x  "The music film is a part of TOHO animation's 10th anniversary project."
#     4x  'Short animation by Komazaki Tomomi.'

# %% [markdown]
# **Risultati indagine duplicati:**
#
# - **456 righe coinvolte** in duplicazioni (168 testi univoci distinti). Il numero sembra diverso dal numero 288 riportato da `analyze()` perché quella cifra conta solo le copie non-prime, mentre qui si contano tutte le righe con testo non unico.
# - Il testo più frequente (23×) è il boilerplate `"No synopsis has been added for this series yet..."` che rimuoviamo successivamente.
# - Tutti gli altri duplicati sono descrizioni brevi e generiche di cortometraggi d'autore o descrizioni standard di release. Si tratta di contenuto corretto.
# - **Nessun nuovo pattern boilerplate** da rimuovere. I duplicati rimanenti sono legittimi.

# %% [markdown]
# **Sinossi contenenti URL e `@`:**
#
# `analyze()` riporta 3 sinossi con URL e 38 con `@`. Verifichiamo il contesto per determinare se si tratta di contenuto legittimo o artefatti da rimuovere.

# %%
import re

# Sinossi contenenti URL
url_mask_syn = df_details['synopsis'].str.contains(r'https?://\S+', regex=True, na=False)
print(f'Sinossi con URL: {url_mask_syn.sum()}')
print()

df_url = df_details.loc[url_mask_syn, ['mal_id', 'title', 'type']].copy()
df_url['synopsis'] = df_details.loc[url_mask_syn, 'synopsis'].str.findall(r'https?://\S+')
df_url = df_url.explode('synopsis').reset_index(drop=True)
print(df_url.to_string(index=False))

print()
print('─' * 80)
print()

# Sinossi contenenti '@'
at_mask_syn = df_details['synopsis'].str.contains(r'@', regex=False, na=False)
print(f'Sinossi con @: {at_mask_syn.sum()}')
print()

df_at = df_details.loc[at_mask_syn, ['mal_id', 'title']].copy()
df_at['synopsis'] = df_details.loc[at_mask_syn, 'synopsis'].str.findall(r'\S*@\S+')
df_at = df_at.explode('synopsis').reset_index(drop=True)
print(df_at.to_string(index=False))
# Out:
# Sinossi con URL: 3
#
#  mal_id                       title    type                                       synopsis
#   47634 Kamen Senshi Lavithunder CM Special                  https://vgmdb.net/album/54883
#    6230        Kyokujitsu no Kantai     OVA http://en.wikipedia.org/wiki/Konpeki_no_Kantai
#   43196              Luotuo Xian Wu   Movie               https://jouz.myblog.arts.ac.uk/,
#
# ────────────────────────────────────────────────────────────────────────────────
#
# Sinossi con @: 38
#
#  mal_id                                                                                title                 synopsis
#   35651                                                                  Aozora Under Girls!               iDOLM@STER
#   48814                                                                                 Blue                     m@e.
#   34489                                Cinderella Girls Gekijou: 5-shuunen Kinen Short Anime               iDOLM@STER
#   35346                                   Cinderella Girls Gekijou: Kayou Cinderella Theater               iDOLM@STER
#   36500                        Cinderella Girls Gekijou: Kayou Cinderella Theater 2nd Season               iDOLM@STER
#   37424                        Cinderella Girls Gekijou: Kayou Cinderella Theater 3rd Season               iDOLM@STER
#   39654                        Cinderella Girls Gekijou: Kayou Cinderella Theater 4th Season               iDOLM@STER
#   51234                                                                    Eternity Memories               iDOLM@STER
#   58598                                                             Guruguru@Mawaru@Mawaluna Guruguru@Mawaru@Mawaluna
#   28439                                                        Hatsune Miku x Tetsuya Nomura     Positivity"@Wallplay
#    3406                                                      iDOLM@STER Xenoglossia Specials               iDOLM@STER
#    4130                                                         Petit Eva: Evangelion@School     ~Evangelion@School~,
#   21073                                                   Puchimas!!: Petit Petit iDOLM@STER             IDOLM@STER",
#   15649                                                          Puchimas!: Petit iDOLM@STER             IDOLM@STER",
#   15781                                                Puchimas!: Petit iDOLM@STER Episode 0              iDOLM@STER-
#   51509                                                                         Seikan Sekai               IDOLM@STER
#   51842                                                                          Seven Count               Idolm@ster
#   38271                                                     Spice Paradise: Curry Meshi Ver.               IDOLM@STER
#   30344                                           The iDOLM@STER Cinderella Girls 2nd Season               iDOLM@STER
#   32174                  The iDOLM@STER Cinderella Girls: Anytime, Anywhere with Cinderella.               iDOLM@STER
#   30218                                     The iDOLM@STER Cinderella Girls: Special Program               iDOLM@STER
#   40693                                           The iDOLM@STER Cinderella Girls: Spin-off!               Idolm@ster
#   42882  The iDOLM@STER Cinderella Girls: Starlight Stage - 5-shuunen Kinen "Go Just Go!" PV              iDOLM@STER:
#   37124 THE iDOLM@STER Cinderella Girls: Starlight Stage - Shinshun! Happy New Year Campaign              iDOLM@STER:
#   55393                                 The IDOLM@STER Cinderella Girls: Starlight Stage CMs               IDOLM@STER
#   55517                                          The iDOLM@STER Cinderella Girls: U149 Recap               IDOLM@STER
#   55802                                        The iDOLM@STER Cinderella Girls: U149 Special               IDOLM@STER
#   42385                                                         The iDOLM@STER Million Live!               IDOLM@STER
#   31894                                The iDOLM@STER Million Live! "Dreaming!" Animation PV               iDOLM@STER
#   31894                                The iDOLM@STER Million Live! "Dreaming!" Animation PV               IDOLM@STER
#   31894                                The iDOLM@STER Million Live! "Dreaming!" Animation PV                  THE@TER
#   61156                                      The iDOLM@STER Million Live! Itsuka, Mannaka de               iDOLM@STER
#   61456                                          The iDOLM@STER Million Live!: The Backstage               iDOLM@STER
#   36186                                    The iDOLM@STER Prologue SideM: Episode of Jupiter               iDOLM@STER
#   34915                                                                 The iDOLM@STER SideM               Idolm@ster
#   36529                             The iDOLM@STER SideM: 315 Variety Pack! Made In Passion!               iDOLM@STER
#   38562                    The iDOLM@STER SideM: Wake Atte Mini! - Shoshi Kantetsu Daisouji!               iDOLM@STER
#   49735                                       The iDOLM@STER SideM: Wake Atte Mini! Specials               iDOLM@STER
#    8449                                                                       Togainu no Chi                  Bl@ster
#    8449                                                                       Togainu no Chi                 Bl@ster.
#   49661                                                                              Voy@ger                  Voy@ger
#   49661                                                                              Voy@ger               iDOLM@STER

# %% [markdown]
# - Tutte le sinossi contenenti URL sono citazioni di fonte.
# - In tutti i casi contenenti `@`, si tratta di un carattere intenzionale di titoli o nomi ufficiali.
# - Rimuoviamo solo i testi bolerplate impostandoli a null.
#
# **Nessuna ulteriore pulizia necessaria.**

# %%
pattern = r'^No synopsis has been added for this series yet'
mask_bp = df_details['synopsis'].str.contains(pattern, regex=True, na=False)
print(f'Righe con sinossi boilerplate: {mask_bp.sum()}')
print(df_details.loc[mask_bp, 'synopsis'].value_counts().to_string())

df_details.loc[mask_bp, 'synopsis'] = np.nan
print(f'\nNull in synopsis dopo pulizia: {df_details["synopsis"].isna().sum():,}')
# Out:
# Righe con sinossi boilerplate: 25
# synopsis
# No synopsis has been added for this series yet.\n\nClick here to update this information.     23
# No synopsis has been added for this series yet.                                                1
# No synopsis has been added for this series yet. \n\nClick here to update this information.     1
#
# Null in synopsis dopo pulizia: 5,152

# %% [markdown]
# ### 2.13 `rank`
#
# Classifica globale basata sullo score. I null sono attesi in quanto anime senza score non ricevono un rank.

# %%
analyze(df_details['rank'])

# %% [markdown]
# **Osservazioni:**
# - **6.958 valori nulli** (~24.0%): strutturali, anime non classificati (score assente).
# - **17.765 valori unici su 21.997 non-null**: 4.232 anime condividono il rank con almeno un altro quando più anime hanno lo stesso score.
# - **Conversione dtype**: da `float64` a `Int64` dato che i rank sono interi.
# - Si nota la presenza di bucchi e rank condivisi (Max = 22,020 mentre il totale di valori non nulli è 21,977). Questo è dovuto al fatto che `rank` è un attributo calcolato da MAL, dove se più anime condividono lo stesso score, ricevono lo stesso rank. Non si tratta di errori nei dati e modificare questi valori produrrebbe una colonna diversa da quella originale.
#
# **Nessuna ulteriore pulizia necessaria.**

# %%
df_details['rank'] = df_details['rank'].astype('Int64')
print(f'rank dtype: {df_details["rank"].dtype}')

# %% [markdown]
# ### 2.14 `popularity`
#
# Classifica di popolarità basata sul numero di utenti che hanno l'anime nella propria lista.

# %%
analyze(df_details['popularity'])

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 28.955 record hanno un valore.
# - **Dtype corretto**: `int64`.
# - Si nota la presenza di bucchi e popolarità condivise (Max = 28,998 mentre il totale di valori non nulli è 28,955). Questo è dovuto al fatto che `popularity` è un attributo calcolato da MAL, dove se più anime condividono lo stesso numero di `members`, ricevono la stessa popolarità. Non si tratta di errori nei dati e modificare questi valori produrrebbe una colonna diversa da quella originale.
#
# **Nessuna pulizia necessaria.**

# %% [markdown]
# ### 2.15 `members`
#
# Numero di utenti MAL che hanno l'anime nella propria lista.

# %%
analyze(df_details['members'])

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 28.955 record hanno un valore.
# - **Dtype corretto**: `int64`.
#
# **Nessuna pulizia necessaria**

# %% [markdown]
# ### 2.16 `favorites`
#
# Numero di utenti che hanno aggiunto l'anime ai propri preferiti.

# %%
analyze(df_details['favorites'])

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 28.955 record hanno un valore.
# - **Dtype corretto**: `int64`.
# - Il 44.6% dei valori è 0. Non è un anomalia ma si tratta di anime poco conosciuti.
#
# Nessuna pulizia necessaria.
